# %% [markdown]
# ## Машинное обучение 1, ММП ВМК МГУ
#
# ## Семинар 1

# %% [markdown]
# ## Машинное обучение: основные понятия

# %% [markdown]
# ### Задача машинного обучения - написать алгоритм, способный самостоятельно обучаться и  настраиваться на решение конкретной задачи.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %%
x_train = np.sort(np.random.rand(50))*10 - 5
y_train = x_train**2
x_train += 18
y_train += 128.5

# %%
x_train, y_train
# Out:
# (array([13.3086626 , 13.33574332, 13.41203692, 13.72115439, 13.92834359,
#         14.21128857, 14.24039472, 14.42014219, 14.8122632 , 15.63391506,
#         15.79792307, 16.21915425, 16.44823462, 16.57791932, 17.15789531,
#         17.86701079, 17.93525565, 18.11979882, 18.13490591, 18.15409788,
#         18.16515137, 18.17265749, 18.28186834, 18.58861008, 18.70097394,
#         19.3317504 , 19.41635887, 19.58210101, 19.69556604, 19.78520755,
#         20.19240365, 20.30024077, 20.44154991, 20.86502704, 20.94652397,
#         21.15919253, 21.20080828, 21.25394094, 21.53980468, 21.65232751,
#         21.6704985 , 21.71905968, 21.75998462, 21.78725759, 22.04856095,
#         22.10515414, 22.57398638, 22.70548488, 22.79837775, 22.93701094]),
#  array([150.50864663, 150.25529041, 149.54940523, 146.80851977,
#         145.07838592, 142.85433433, 142.63463188, 141.31538195,
#         138.66166589, 134.09835793, 133.34914283, 131.67141158,
#         130.90797578, 130.52231347, 129.2091403 , 128.51768613,
#         128.50419183, 128.51435176, 128.51819961, 128.52374616,
#         128.52727497, 128.52981061, 128.57944976, 128.84646182,
#         128.99136447, 130.27355913, 130.50607246, 131.00304361,
#         131.3749442 , 131.68696599, 133.30663378, 133.79110758,
#         134.46116594, 136.70837992, 137.18200349, 138.48049746,
#         138.74517363, 139.08813167, 141.03021715, 141.83949623,
#         141.97255927, 142.33140494, 142.63748431, 142.84332002,
#         144.89084575, 145.35229049, 149.42135142, 150.64158799,
#         151.52442903, 152.87407699]))

# %%
plt.scatter(x_train, y_train)
plt.xlabel('feature')
plt.ylabel('label')
plt.title('Зависимость целевой переменной от признака')
plt.grid()
plt.show()

# %%
x_test = np.array([0, 21, 26, -15.7])

# %% [markdown]
# y_test = ?

# %% [markdown]
# -
#
# -
#
# -
#
# -
#
# -
#
# -
#
# -
#
# -
#
# -
#
# -

# %% [markdown]
# #### Простое решение - использовать силу матана!
#
# Пусть уравнение параболы $ y = ax^2 + bx + c$
#
# Выбираем 3 точки, подставляем и решаем СЛАУ.
#
# **Или**
#
# Известно что x - координата вершины равняется $\frac{-b}{2a}$
#
# Случайно выбираем 2 точки, подставляем и решаем СЛАУ.

# %% [markdown]
# **Или**
#
#  Любой другой метод.
#
#  В любом случае, еси вы смогли его запрограммировать, то поздравляю. Вы написали алгоритм машинного обучения!

# %% [markdown]
# #### **Пример простой но удовлетворяет всем "критериям" задачи ML**
#
# Есть обучающая выборка X_train, Y_train, содержащая информацию о прецедентах.
#
# Есть программа, которая на основании этих прецедентов настраивает свои внутренние параметры.

# %% [markdown]
# ####Теперь усложним задачу. Пусть данные зашумлены.

# %%
x_train = np.sort(np.random.rand(50))*10 - 5
y_train = x_train**2
x_train += 18
y_train += (np.random.rand(50)*5 - 2.5)
y_train += 128.5
plt.scatter(x_train, y_train)
plt.xlabel('feature')
plt.ylabel('label')
plt.title('Зависимость целевой переменной от признака')
plt.grid()
plt.show()

# %% [markdown]
# Теперь мы не можем точно решить задачу. Можем лишь аппроксимировать решение с определенной точностью. Функция, по которой измеряется точность модели называется **функционал качества**. Она может быть подобрана, исходя из задачи.
#
# Вариант решения: надо аппроксимировать полиномом с минимальным квадратичным отклонением от обучающей выборки. Ниже реализована программа для аппроксимации.

# %%
def f1(x):
  ret = 0
  coefs = np.ones(3)
  x = np.array([x])
  pows = np.arange(coefs.shape[0])
  return ((x[:, np.newaxis]**pows[np.newaxis, :])*coefs[np.newaxis, :]).sum()

# %%
def f(x, coefs):
  ret = 0
  pows = np.arange(coefs.shape[0])
  return ((x[:, np.newaxis]**pows[np.newaxis, :])*coefs[np.newaxis, :]).sum(1)

# %%
def train_f(N, pow, x_train, y_train, lr, initial):
  coefs = initial#np.ones(pow)#random.rand
  grad = 0
  for i in range(N):
    print(i, ((f(x_train, coefs) - y_train)**2).mean())
    a = f(x_train, coefs)
    #print(2*(a - y_train)[np.newaxis, :])
    grad = 2*(a - y_train)[np.newaxis, :]*(x_train[np.newaxis, :]**np.arange(pow)[:, np.newaxis])
    grad = grad.sum(1)/x_train.shape[0]
    lambdas = minimize(lambda lam: ((f(x_train, coefs-grad*lam) - y_train)**2).sum(), np.zeros_like(coefs))['x']
#    print(lambdas)
    coefs -= grad*lambdas*lr
    #lr /= 2
    #print('lr = ', lr)
  return coefs

# %%
#f(x_train, np.ones(3)) - y_train

# %% [markdown]
# #### Предположим что мы не знаем что это парабола. Наша задача - аппроксимировать множество точек полиномом какой-то степени. Степень подбираем самостоятельно. Параметры модели, которые инженер машинного обучения подбирает сам (то есть, они НЕ настраиваются в процессе обучения) называются **ГИПЕРПАРАМЕТРЫ**. Степень полинома в данном случае - гиперпараметр.

# %%
coefs = train_f(5000, 1, x_train, y_train, 0.1, np.zeros(1)) #0.001 норм
# Out:
# 0 18713.83789776305
# 1 11994.624043705393
# 2 7694.327177108487
# 3 4942.137182486469
# 4 3180.735585928379
# 5 2053.4385641312015
# 6 1331.968470181008
# 7 870.2276100528841
# 8 574.7134595708848
# 9 385.5844032624051
# 10 264.54180722497796
# 11 187.07454576102452
# 12 137.49549842409434
# 13 105.76490812845913
# 14 85.45733033925275
# 15 72.46048055416061
# 16 64.14249669170162
# 17 58.81898701972776
# 18 55.411940829664516
# 19 53.23143126802403
# 20 51.83590514857415
# 21 50.94276843212622
# 22 50.37116093359952
# 23 50.00533213454244
# 24 49.77120170314593
# 25 49.62135822705213
# 26 49.525458402352115
# 27 49.46408251454409
# 28 49.42480194634697
# 29 49.39966238270081
# 30 49.38357306196726
# 31 49.373275896697784
# 32 49.36668571092534
# 33 49.36246799203095
# 34 49.35976865193856
# 35 49.35804107427943
# 36 49.356935424577586
# 37 49.3562278087684
# 38 49.35577493465052
# 39 49.35548509521508
# 40 49.3552995979764
# 41 49.35518087974364
# 42 49.355104900074664
# 43 49.35505627308655
# 44 49.35502515181413
# 45 49.35500523419978
# 46 49.354992486926605
# 47 49.35498432867177
# 48 49.35497910738869
# 49 49.354975765767506
# 50 49.35497362712996
# 51 49.354972258401915
# 52 49.35497138241596
# 53 49.35497082178497
# 54 49.35497046298112
# 55 49.354970233346656
# 56 49.35497008638061
# 57 49.35496999232233
# 58 49.354969932125044
# 59 49.35496989359877
# 60 49.354969868941964
# 61 49.3549698531616
# 62 49.354969843062165
# 63 49.35496983659853
# 64 49.35496983246181
# 65 49.35496982981431
# 66 49.35496982811989
# 67 49.35496982703548
# 68 49.35496982634146
# 69 49.35496982589728
# 70 49.354969825613004
# 71 49.35496982543107
# 72 49.354969825314626
# 73 49.35496982524011
# 74 49.35496982519242
# 75 49.35496982516189
# 76 49.354969825142355
# 77 49.35496982512985
# 78 49.354969825121856
# 79 49.35496982511673
# 80 49.35496982511345
# 81 49.354969825111354
# 82 49.35496982511001
# 83 49.354969825109166
# 84 49.354969825108604
# 85 49.354969825108256
# 86 49.35496982510803
# 87 49.354969825107894
# 88 49.354969825107794
# 89 49.35496982510774
# 90 49.3549698251077
# 91 49.354969825107666
# 92 49.354969825107645
# 93 49.35496982510764
# 94 49.35496982510764
# 95 49.35496982510763
# 96 49.35496982510763
# 97 49.35496982510763
# 98 49.35496982510763
# 99 49.35496982510762
# 100 49.35496982510764
# 101 49.35496982510763
# 102 49.35496982510763
# 103 49.35496982510762
# 104 49.35496982510762
# 105 49.35496982510763
# 106 49.35496982510763
# 107 49.35496982510762
# 108 49.35496982510763
# 109 49.35496982510764
# 110 49.35496982510763
# 111 49.35496982510762
# 112 49.35496982510762
# 113 49.35496982510763
# 114 49.35496982510763
# 115 49.35496982510762
# 116 49.35496982510762
# 117 49.35496982510763
# 118 49.35496982510762
# 119 49.35496982510763
# 120 49.35496982510762
# 121 49.35496982510763
# 122 49.35496982510762
# 123 49.35496982510763
# 124 49.35496982510763
# 125 49.35496982510763
# 126 49.35496982510763
# 127 49.35496982510763
# 128 49.35496982510763
# 129 49.35496982510763
# 130 49.35496982510763
# 131 49.35496982510763
# 132 49.35496982510762
# 133 49.35496982510763
# 134 49.35496982510763
# 135 49.35496982510762
# 136 49.35496982510763
# 137 49.35496982510763
# 138 49.35496982510762
# 139 49.35496982510762
# 140 49.35496982510763
# 141 49.35496982510763
# 142 49.35496982510762
# 143 49.35496982510762
# 144 49.35496982510762
# 145 49.35496982510763
# 146 49.35496982510763
# 147 49.35496982510762
# 148 49.35496982510763
# 149 49.35496982510763
# 150 49.35496982510763
# 151 49.35496982510763
# 152 49.35496982510763
# 153 49.35496982510762
# 154 49.35496982510764
# 155 49.35496982510763
# 156 49.35496982510762
# 157 49.35496982510763
# 158 49.35496982510762
# 159 49.35496982510762
# 160 49.35496982510762
# 161 49.35496982510762
# 162 49.35496982510762
# 163 49.35496982510762
# 164 49.35496982510762
# 165 49.35496982510762
# 166 49.35496982510762
# 167 49.35496982510762
# 168 49.35496982510762
# 169 49.35496982510762
# 170 49.35496982510762
# 171 49.35496982510762
# 172 49.35496982510762
# 173 49.35496982510762
# 174 49.35496982510762
# 175 49.35496982510762
# 176 49.35496982510762
# 177 49.35496982510762
# 178 49.35496982510762
# 179 49.35496982510762
# 180 49.35496982510762
# 181 49.35496982510762
# 182 49.35496982510762
# 183 49.35496982510762
# 184 49.35496982510762
# 185 49.35496982510762
# 186 49.35496982510762
# 187 49.35496982510762
# 188 49.35496982510762
# 189 49.35496982510762
# 190 49.35496982510762
# 191 49.35496982510762
# 192 49.35496982510762
# 193 49.35496982510762
# 194 49.35496982510762
# 195 49.35496982510762
# 196 49.35496982510762
# 197 49.35496982510762
# 198 49.35496982510762
# 199 49.35496982510762
# 200 49.35496982510762
# 201 49.35496982510762
# 202 49.35496982510762
# 203 49.35496982510762
# 204 49.35496982510762
# 205 49.35496982510762
# 206 49.35496982510762
# 207 49.35496982510762
# 208 49.35496982510762
# 209 49.35496982510762
# 210 49.35496982510762
# 211 49.35496982510762
# 212 49.35496982510762
# 213 49.35496982510762
# 214 49.35496982510762
# 215 49.35496982510762
# 216 49.35496982510762
# 217 49.35496982510762
# 218 49.35496982510762
# 219 49.35496982510762
# 220 49.35496982510762
# 221 49.35496982510762
# 222 49.35496982510762
# 223 49.35496982510762
# 224 49.35496982510762
# 225 49.35496982510762
# 226 49.35496982510762
# 227 49.35496982510762
# 228 49.35496982510762
# 229 49.35496982510762
# 230 49.35496982510762
# 231 49.35496982510762
# 232 49.35496982510762
# 233 49.35496982510762
# 234 49.35496982510762
# 235 49.35496982510762
# 236 49.35496982510762
# 237 49.35496982510762
# 238 49.35496982510762
# 239 49.35496982510762
# 240 49.35496982510762
# 241 49.35496982510762
# 242 49.35496982510762
# 243 49.35496982510762
# 244 49.35496982510762
# 245 49.35496982510762
# 246 49.35496982510762
# 247 49.35496982510762
# 248 49.35496982510762
# 249 49.35496982510762
# 250 49.35496982510762
# 251 49.35496982510762
# 252 49.35496982510762
# 253 49.35496982510762
# 254 49.35496982510762
# 255 49.35496982510762
# 256 49.35496982510762
# 257 49.35496982510762
# 258 49.35496982510762
# 259 49.35496982510762
# 260 49.35496982510762
# 261 49.35496982510762
# 262 49.35496982510762
# 263 49.35496982510762
# 264 49.35496982510762
# 265 49.35496982510762
# 266 49.35496982510762
# 267 49.35496982510762
# 268 49.35496982510762
# 269 49.35496982510762
# 270 49.35496982510762
# 271 49.35496982510762
# 272 49.35496982510762
# 273 49.35496982510762
# 274 49.35496982510762
# 275 49.35496982510762
# 276 49.35496982510762
# 277 49.35496982510762
# 278 49.35496982510762
# 279 49.35496982510762
# 280 49.35496982510762
# 281 49.35496982510762
# 282 49.35496982510762
# 283 49.35496982510762
# 284 49.35496982510762
# 285 49.35496982510762
# 286 49.35496982510762
# 287 49.35496982510762
# 288 49.35496982510762
# 289 49.35496982510762
# 290 49.35496982510762
# 291 49.35496982510762
# 292 49.35496982510762
# 293 49.35496982510762
# 294 49.35496982510762
# 295 49.35496982510762
# 296 49.35496982510762
# 297 49.35496982510762
# 298 49.35496982510762
# 299 49.35496982510762
# 300 49.35496982510762
# 301 49.35496982510762
# 302 49.35496982510762
# 303 49.35496982510762
# 304 49.35496982510762
# 305 49.35496982510762
# 306 49.35496982510762
# 307 49.35496982510762
# 308 49.35496982510762
# 309 49.35496982510762
# 310 49.35496982510762
# 311 49.35496982510762
# 312 49.35496982510762
# 313 49.35496982510762
# 314 49.35496982510762
# 315 49.35496982510762
# 316 49.35496982510762
# 317 49.35496982510762
# 318 49.35496982510762
# 319 49.35496982510762
# 320 49.35496982510762
# 321 49.35496982510762
# 322 49.35496982510762
# 323 49.35496982510762
# 324 49.35496982510762
# 325 49.35496982510762
# 326 49.35496982510762
# 327 49.35496982510762
# 328 49.35496982510762
# 329 49.35496982510762
# 330 49.35496982510762
# 331 49.35496982510762
# 332 49.35496982510762
# 333 49.35496982510762
# 334 49.35496982510762
# 335 49.35496982510762
# 336 49.35496982510762
# 337 49.35496982510762
# 338 49.35496982510762
# 339 49.35496982510762
# 340 49.35496982510762
# 341 49.35496982510762
# 342 49.35496982510762
# 343 49.35496982510762
# 344 49.35496982510762
# 345 49.35496982510762
# 346 49.35496982510762
# 347 49.35496982510762
# 348 49.35496982510762
# 349 49.35496982510762
# 350 49.35496982510762
# 351 49.35496982510762
# 352 49.35496982510762
# 353 49.35496982510762
# 354 49.35496982510762
# 355 49.35496982510762
# 356 49.35496982510762
# 357 49.35496982510762
# 358 49.35496982510762
# 359 49.35496982510762
# 360 49.35496982510762
# 361 49.35496982510762
# 362 49.35496982510762
# 363 49.35496982510762
# 364 49.35496982510762
# 365 49.35496982510762
# 366 49.35496982510762
# 367 49.35496982510762
# 368 49.35496982510762
# 369 49.35496982510762
# 370 49.35496982510762
# 371 49.35496982510762
# 372 49.35496982510762
# 373 49.35496982510762
# 374 49.35496982510762
# 375 49.35496982510762
# 376 49.35496982510762
# 377 49.35496982510762
# 378 49.35496982510762
# 379 49.35496982510762
# 380 49.35496982510762
# 381 49.35496982510762
# 382 49.35496982510762
# 383 49.35496982510762
# 384 49.35496982510762
# 385 49.35496982510762
# 386 49.35496982510762
# 387 49.35496982510762
# 388 49.35496982510762
# 389 49.35496982510762
# 390 49.35496982510762
# 391 49.35496982510762
# 392 49.35496982510762
# 393 49.35496982510762
# 394 49.35496982510762
# 395 49.35496982510762
# 396 49.35496982510762
# 397 49.35496982510762
# 398 49.35496982510762
# 399 49.35496982510762
# 400 49.35496982510762
# 401 49.35496982510762
# 402 49.35496982510762
# 403 49.35496982510762
# 404 49.35496982510762
# 405 49.35496982510762
# 406 49.35496982510762
# 407 49.35496982510762
# 408 49.35496982510762
# 409 49.35496982510762
# 410 49.35496982510762
# 411 49.35496982510762
# 412 49.35496982510762
# 413 49.35496982510762
# 414 49.35496982510762
# 415 49.35496982510762
# 416 49.35496982510762
# 417 49.35496982510762
# 418 49.35496982510762
# 419 49.35496982510762
# 420 49.35496982510762
# 421 49.35496982510762
# 422 49.35496982510762
# 423 49.35496982510762
# 424 49.35496982510762
# 425 49.35496982510762
# 426 49.35496982510762
# 427 49.35496982510762
# 428 49.35496982510762
# 429 49.35496982510762
# 430 49.35496982510762
# 431 49.35496982510762
# 432 49.35496982510762
# 433 49.35496982510762
# 434 49.35496982510762
# 435 49.35496982510762
# 436 49.35496982510762
# 437 49.35496982510762
# 438 49.35496982510762
# 439 49.35496982510762
# 440 49.35496982510762
# 441 49.35496982510762
# 442 49.35496982510762
# 443 49.35496982510762
# 444 49.35496982510762
# 445 49.35496982510762
# 446 49.35496982510762
# 447 49.35496982510762
# 448 49.35496982510762
# 449 49.35496982510762
# 450 49.35496982510762
# 451 49.35496982510762
# 452 49.35496982510762
# 453 49.35496982510762
# 454 49.35496982510762
# 455 49.35496982510762
# 456 49.35496982510762
# 457 49.35496982510762
# 458 49.35496982510762
# 459 49.35496982510762
# 460 49.35496982510762
# 461 49.35496982510762
# 462 49.35496982510762
# 463 49.35496982510762
# 464 49.35496982510762
# 465 49.35496982510762
# 466 49.35496982510762
# 467 49.35496982510762
# 468 49.35496982510762
# 469 49.35496982510762
# 470 49.35496982510762
# 471 49.35496982510762
# 472 49.35496982510762
# 473 49.35496982510762
# 474 49.35496982510762
# 475 49.35496982510762
# 476 49.35496982510762
# 477 49.35496982510762
# 478 49.35496982510762
# 479 49.35496982510762
# 480 49.35496982510762
# 481 49.35496982510762
# 482 49.35496982510762
# 483 49.35496982510762
# 484 49.35496982510762
# 485 49.35496982510762
# 486 49.35496982510762
# 487 49.35496982510762
# 488 49.35496982510762
# 489 49.35496982510762
# 490 49.35496982510762
# 491 49.35496982510762
# 492 49.35496982510762
# 493 49.35496982510762
# 494 49.35496982510762
# 495 49.35496982510762
# 496 49.35496982510762
# 497 49.35496982510762
# 498 49.35496982510762
# 499 49.35496982510762
# 500 49.35496982510762
# 501 49.35496982510762
# 502 49.35496982510762
# 503 49.35496982510762
# 504 49.35496982510762
# 505 49.35496982510762
# 506 49.35496982510762
# 507 49.35496982510762
# 508 49.35496982510762
# 509 49.35496982510762
# 510 49.35496982510762
# 511 49.35496982510762
# 512 49.35496982510762
# 513 49.35496982510762
# 514 49.35496982510762
# 515 49.35496982510762
# 516 49.35496982510762
# 517 49.35496982510762
# 518 49.35496982510762
# 519 49.35496982510762
# 520 49.35496982510762
# 521 49.35496982510762
# 522 49.35496982510762
# 523 49.35496982510762
# 524 49.35496982510762
# 525 49.35496982510762
# 526 49.35496982510762
# 527 49.35496982510762
# 528 49.35496982510762
# 529 49.35496982510762
# 530 49.35496982510762
# 531 49.35496982510762
# 532 49.35496982510762
# 533 49.35496982510762
# 534 49.35496982510762
# 535 49.35496982510762
# 536 49.35496982510762
# 537 49.35496982510762
# 538 49.35496982510762
# 539 49.35496982510762
# 540 49.35496982510762
# 541 49.35496982510762
# 542 49.35496982510762
# 543 49.35496982510762
# 544 49.35496982510762
# 545 49.35496982510762
# 546 49.35496982510762
# 547 49.35496982510762
# 548 49.35496982510762
# 549 49.35496982510762
# 550 49.35496982510762
# 551 49.35496982510762
# 552 49.35496982510762
# 553 49.35496982510762
# 554 49.35496982510762
# 555 49.35496982510762
# 556 49.35496982510762
# 557 49.35496982510762
# 558 49.35496982510762
# 559 49.35496982510762
# 560 49.35496982510762
# 561 49.35496982510762
# 562 49.35496982510762
# 563 49.35496982510762
# 564 49.35496982510762
# 565 49.35496982510762
# 566 49.35496982510762
# 567 49.35496982510762
# 568 49.35496982510762
# 569 49.35496982510762
# 570 49.35496982510762
# 571 49.35496982510762
# 572 49.35496982510762
# 573 49.35496982510762
# 574 49.35496982510762
# 575 49.35496982510762
# 576 49.35496982510762
# 577 49.35496982510762
# 578 49.35496982510762
# 579 49.35496982510762
# 580 49.35496982510762
# 581 49.35496982510762
# 582 49.35496982510762
# 583 49.35496982510762
# 584 49.35496982510762
# 585 49.35496982510762
# 586 49.35496982510762
# 587 49.35496982510762
# 588 49.35496982510762
# 589 49.35496982510762
# 590 49.35496982510762
# 591 49.35496982510762
# 592 49.35496982510762
# 593 49.35496982510762
# 594 49.35496982510762
# 595 49.35496982510762
# 596 49.35496982510762
# 597 49.35496982510762
# 598 49.35496982510762
# 599 49.35496982510762
# 600 49.35496982510762
# 601 49.35496982510762
# 602 49.35496982510762
# 603 49.35496982510762
# 604 49.35496982510762
# 605 49.35496982510762
# 606 49.35496982510762
# 607 49.35496982510762
# 608 49.35496982510762
# 609 49.35496982510762
# 610 49.35496982510762
# 611 49.35496982510762
# 612 49.35496982510762
# 613 49.35496982510762
# 614 49.35496982510762
# 615 49.35496982510762
# 616 49.35496982510762
# 617 49.35496982510762
# 618 49.35496982510762
# 619 49.35496982510762
# 620 49.35496982510762
# 621 49.35496982510762
# 622 49.35496982510762
# 623 49.35496982510762
# 624 49.35496982510762
# 625 49.35496982510762
# 626 49.35496982510762
# 627 49.35496982510762
# 628 49.35496982510762
# 629 49.35496982510762
# 630 49.35496982510762
# 631 49.35496982510762
# 632 49.35496982510762
# 633 49.35496982510762
# 634 49.35496982510762
# 635 49.35496982510762
# 636 49.35496982510762
# 637 49.35496982510762
# 638 49.35496982510762
# 639 49.35496982510762
# 640 49.35496982510762
# 641 49.35496982510762
# 642 49.35496982510762
# 643 49.35496982510762
# 644 49.35496982510762
# 645 49.35496982510762
# 646 49.35496982510762
# 647 49.35496982510762
# 648 49.35496982510762
# 649 49.35496982510762
# 650 49.35496982510762
# 651 49.35496982510762
# 652 49.35496982510762
# 653 49.35496982510762
# 654 49.35496982510762
# 655 49.35496982510762
# 656 49.35496982510762
# 657 49.35496982510762
# 658 49.35496982510762
# 659 49.35496982510762
# 660 49.35496982510762
# 661 49.35496982510762
# 662 49.35496982510762
# 663 49.35496982510762
# 664 49.35496982510762
# 665 49.35496982510762
# 666 49.35496982510762
# 667 49.35496982510762
# 668 49.35496982510762
# 669 49.35496982510762
# 670 49.35496982510762
# 671 49.35496982510762
# 672 49.35496982510762
# 673 49.35496982510762
# 674 49.35496982510762
# 675 49.35496982510762
# 676 49.35496982510762
# 677 49.35496982510762
# 678 49.35496982510762
# 679 49.35496982510762
# 680 49.35496982510762
# 681 49.35496982510762
# 682 49.35496982510762
# 683 49.35496982510762
# 684 49.35496982510762
# 685 49.35496982510762
# 686 49.35496982510762
# 687 49.35496982510762
# 688 49.35496982510762
# 689 49.35496982510762
# 690 49.35496982510762
# 691 49.35496982510762
# 692 49.35496982510762
# 693 49.35496982510762
# 694 49.35496982510762
# 695 49.35496982510762
# 696 49.35496982510762
# 697 49.35496982510762
# 698 49.35496982510762
# 699 49.35496982510762
# 700 49.35496982510762
# 701 49.35496982510762
# 702 49.35496982510762
# 703 49.35496982510762
# 704 49.35496982510762
# 705 49.35496982510762
# 706 49.35496982510762
# 707 49.35496982510762
# 708 49.35496982510762
# 709 49.35496982510762
# 710 49.35496982510762
# 711 49.35496982510762
# 712 49.35496982510762
# 713 49.35496982510762
# 714 49.35496982510762
# 715 49.35496982510762
# 716 49.35496982510762
# 717 49.35496982510762
# 718 49.35496982510762
# 719 49.35496982510762
# 720 49.35496982510762
# 721 49.35496982510762
# 722 49.35496982510762
# 723 49.35496982510762
# 724 49.35496982510762
# 725 49.35496982510762
# 726 49.35496982510762
# 727 49.35496982510762
# 728 49.35496982510762
# 729 49.35496982510762
# 730 49.35496982510762
# 731 49.35496982510762
# 732 49.35496982510762
# 733 49.35496982510762
# 734 49.35496982510762
# 735 49.35496982510762
# 736 49.35496982510762
# 737 49.35496982510762
# 738 49.35496982510762
# 739 49.35496982510762
# 740 49.35496982510762
# 741 49.35496982510762
# 742 49.35496982510762
# 743 49.35496982510762
# 744 49.35496982510762
# 745 49.35496982510762
# 746 49.35496982510762
# 747 49.35496982510762
# 748 49.35496982510762
# 749 49.35496982510762
# 750 49.35496982510762
# 751 49.35496982510762
# 752 49.35496982510762
# 753 49.35496982510762
# 754 49.35496982510762
# 755 49.35496982510762
# 756 49.35496982510762
# 757 49.35496982510762
# 758 49.35496982510762
# 759 49.35496982510762
# 760 49.35496982510762
# 761 49.35496982510762
# 762 49.35496982510762
# 763 49.35496982510762
# 764 49.35496982510762
# 765 49.35496982510762
# 766 49.35496982510762
# 767 49.35496982510762
# 768 49.35496982510762
# 769 49.35496982510762
# 770 49.35496982510762
# 771 49.35496982510762
# 772 49.35496982510762
# 773 49.35496982510762
# 774 49.35496982510762
# 775 49.35496982510762
# 776 49.35496982510762
# 777 49.35496982510762
# 778 49.35496982510762
# 779 49.35496982510762
# 780 49.35496982510762
# 781 49.35496982510762
# 782 49.35496982510762
# 783 49.35496982510762
# 784 49.35496982510762
# 785 49.35496982510762
# 786 49.35496982510762
# 787 49.35496982510762
# 788 49.35496982510762
# 789 49.35496982510762
# 790 49.35496982510762
# 791 49.35496982510762
# 792 49.35496982510762
# 793 49.35496982510762
# 794 49.35496982510762
# 795 49.35496982510762
# 796 49.35496982510762
# 797 49.35496982510762
# 798 49.35496982510762
# 799 49.35496982510762
# 800 49.35496982510762
# 801 49.35496982510762
# 802 49.35496982510762
# 803 49.35496982510762
# 804 49.35496982510762
# 805 49.35496982510762
# 806 49.35496982510762
# 807 49.35496982510762
# 808 49.35496982510762
# 809 49.35496982510762
# 810 49.35496982510762
# 811 49.35496982510762
# 812 49.35496982510762
# 813 49.35496982510762
# 814 49.35496982510762
# 815 49.35496982510762
# 816 49.35496982510762
# 817 49.35496982510762
# 818 49.35496982510762
# 819 49.35496982510762
# 820 49.35496982510762
# 821 49.35496982510762
# 822 49.35496982510762
# 823 49.35496982510762
# 824 49.35496982510762
# 825 49.35496982510762
# 826 49.35496982510762
# 827 49.35496982510762
# 828 49.35496982510762
# 829 49.35496982510762
# 830 49.35496982510762
# 831 49.35496982510762
# 832 49.35496982510762
# 833 49.35496982510762
# 834 49.35496982510762
# 835 49.35496982510762
# 836 49.35496982510762
# 837 49.35496982510762
# 838 49.35496982510762
# 839 49.35496982510762
# 840 49.35496982510762
# 841 49.35496982510762
# 842 49.35496982510762
# 843 49.35496982510762
# 844 49.35496982510762
# 845 49.35496982510762
# 846 49.35496982510762
# 847 49.35496982510762
# 848 49.35496982510762
# 849 49.35496982510762
# 850 49.35496982510762
# 851 49.35496982510762
# 852 49.35496982510762
# 853 49.35496982510762
# 854 49.35496982510762
# 855 49.35496982510762
# 856 49.35496982510762
# 857 49.35496982510762
# 858 49.35496982510762
# 859 49.35496982510762
# 860 49.35496982510762
# 861 49.35496982510762
# 862 49.35496982510762
# 863 49.35496982510762
# 864 49.35496982510762
# 865 49.35496982510762
# 866 49.35496982510762
# 867 49.35496982510762
# 868 49.35496982510762
# 869 49.35496982510762
# 870 49.35496982510762
# 871 49.35496982510762
# 872 49.35496982510762
# 873 49.35496982510762
# 874 49.35496982510762
# 875 49.35496982510762
# 876 49.35496982510762
# 877 49.35496982510762
# 878 49.35496982510762
# 879 49.35496982510762
# 880 49.35496982510762
# 881 49.35496982510762
# 882 49.35496982510762
# 883 49.35496982510762
# 884 49.35496982510762
# 885 49.35496982510762
# 886 49.35496982510762
# 887 49.35496982510762
# 888 49.35496982510762
# 889 49.35496982510762
# 890 49.35496982510762
# 891 49.35496982510762
# 892 49.35496982510762
# 893 49.35496982510762
# 894 49.35496982510762
# 895 49.35496982510762
# 896 49.35496982510762
# 897 49.35496982510762
# 898 49.35496982510762
# 899 49.35496982510762
# 900 49.35496982510762
# 901 49.35496982510762
# 902 49.35496982510762
# 903 49.35496982510762
# 904 49.35496982510762
# 905 49.35496982510762
# 906 49.35496982510762
# 907 49.35496982510762
# 908 49.35496982510762
# 909 49.35496982510762
# 910 49.35496982510762
# 911 49.35496982510762
# 912 49.35496982510762
# 913 49.35496982510762
# 914 49.35496982510762
# 915 49.35496982510762
# 916 49.35496982510762
# 917 49.35496982510762
# 918 49.35496982510762
# 919 49.35496982510762
# 920 49.35496982510762
# 921 49.35496982510762
# 922 49.35496982510762
# 923 49.35496982510762
# 924 49.35496982510762
# 925 49.35496982510762
# 926 49.35496982510762
# 927 49.35496982510762
# 928 49.35496982510762
# 929 49.35496982510762
# 930 49.35496982510762
# 931 49.35496982510762
# 932 49.35496982510762
# 933 49.35496982510762
# 934 49.35496982510762
# 935 49.35496982510762
# 936 49.35496982510762
# 937 49.35496982510762
# 938 49.35496982510762
# 939 49.35496982510762
# 940 49.35496982510762
# 941 49.35496982510762
# 942 49.35496982510762
# 943 49.35496982510762
# 944 49.35496982510762
# 945 49.35496982510762
# 946 49.35496982510762
# 947 49.35496982510762
# 948 49.35496982510762
# 949 49.35496982510762
# 950 49.35496982510762
# 951 49.35496982510762
# 952 49.35496982510762
# 953 49.35496982510762
# 954 49.35496982510762
# 955 49.35496982510762
# 956 49.35496982510762
# 957 49.35496982510762
# 958 49.35496982510762
# 959 49.35496982510762
# 960 49.35496982510762
# 961 49.35496982510762
# 962 49.35496982510762
# 963 49.35496982510762
# 964 49.35496982510762
# 965 49.35496982510762
# 966 49.35496982510762
# 967 49.35496982510762
# 968 49.35496982510762
# 969 49.35496982510762
# 970 49.35496982510762
# 971 49.35496982510762
# 972 49.35496982510762
# 973 49.35496982510762
# 974 49.35496982510762
# 975 49.35496982510762
# 976 49.35496982510762
# 977 49.35496982510762
# 978 49.35496982510762
# 979 49.35496982510762
# 980 49.35496982510762
# 981 49.35496982510762
# 982 49.35496982510762
# 983 49.35496982510762
# 984 49.35496982510762
# 985 49.35496982510762
# 986 49.35496982510762
# 987 49.35496982510762
# 988 49.35496982510762
# 989 49.35496982510762
# 990 49.35496982510762
# 991 49.35496982510762
# 992 49.35496982510762
# 993 49.35496982510762
# 994 49.35496982510762
# 995 49.35496982510762
# 996 49.35496982510762
# 997 49.35496982510762
# 998 49.35496982510762
# 999 49.35496982510762
# 1000 49.35496982510762
# 1001 49.35496982510762
# 1002 49.35496982510762
# 1003 49.35496982510762
# 1004 49.35496982510762
# 1005 49.35496982510762
# 1006 49.35496982510762
# 1007 49.35496982510762
# 1008 49.35496982510762
# 1009 49.35496982510762
# 1010 49.35496982510762
# 1011 49.35496982510762
# 1012 49.35496982510762
# 1013 49.35496982510762
# 1014 49.35496982510762
# 1015 49.35496982510762
# 1016 49.35496982510762
# 1017 49.35496982510762
# 1018 49.35496982510762
# 1019 49.35496982510762
# 1020 49.35496982510762
# 1021 49.35496982510762
# 1022 49.35496982510762
# 1023 49.35496982510762
# 1024 49.35496982510762
# 1025 49.35496982510762
# 1026 49.35496982510762
# 1027 49.35496982510762
# 1028 49.35496982510762
# 1029 49.35496982510762
# 1030 49.35496982510762
# 1031 49.35496982510762
# 1032 49.35496982510762
# 1033 49.35496982510762
# 1034 49.35496982510762
# 1035 49.35496982510762
# 1036 49.35496982510762
# 1037 49.35496982510762
# 1038 49.35496982510762
# 1039 49.35496982510762
# 1040 49.35496982510762
# 1041 49.35496982510762
# 1042 49.35496982510762
# 1043 49.35496982510762
# 1044 49.35496982510762
# 1045 49.35496982510762
# 1046 49.35496982510762
# 1047 49.35496982510762
# 1048 49.35496982510762
# 1049 49.35496982510762
# 1050 49.35496982510762
# 1051 49.35496982510762
# 1052 49.35496982510762
# 1053 49.35496982510762
# 1054 49.35496982510762
# 1055 49.35496982510762
# 1056 49.35496982510762
# 1057 49.35496982510762
# 1058 49.35496982510762
# 1059 49.35496982510762
# 1060 49.35496982510762
# 1061 49.35496982510762
# 1062 49.35496982510762
# 1063 49.35496982510762
# 1064 49.35496982510762
# 1065 49.35496982510762
# 1066 49.35496982510762
# 1067 49.35496982510762
# 1068 49.35496982510762
# 1069 49.35496982510762
# 1070 49.35496982510762
# 1071 49.35496982510762
# 1072 49.35496982510762
# 1073 49.35496982510762
# 1074 49.35496982510762
# 1075 49.35496982510762
# 1076 49.35496982510762
# 1077 49.35496982510762
# 1078 49.35496982510762
# 1079 49.35496982510762
# 1080 49.35496982510762
# 1081 49.35496982510762
# 1082 49.35496982510762
# 1083 49.35496982510762
# 1084 49.35496982510762
# 1085 49.35496982510762
# 1086 49.35496982510762
# 1087 49.35496982510762
# 1088 49.35496982510762
# 1089 49.35496982510762
# 1090 49.35496982510762
# 1091 49.35496982510762
# 1092 49.35496982510762
# 1093 49.35496982510762
# 1094 49.35496982510762
# 1095 49.35496982510762
# 1096 49.35496982510762
# 1097 49.35496982510762
# 1098 49.35496982510762
# 1099 49.35496982510762
# 1100 49.35496982510762
# 1101 49.35496982510762
# 1102 49.35496982510762
# 1103 49.35496982510762
# 1104 49.35496982510762
# 1105 49.35496982510762
# 1106 49.35496982510762
# 1107 49.35496982510762
# 1108 49.35496982510762
# 1109 49.35496982510762
# 1110 49.35496982510762
# 1111 49.35496982510762
# 1112 49.35496982510762
# 1113 49.35496982510762
# 1114 49.35496982510762
# 1115 49.35496982510762
# 1116 49.35496982510762
# 1117 49.35496982510762
# 1118 49.35496982510762
# 1119 49.35496982510762
# 1120 49.35496982510762
# 1121 49.35496982510762
# 1122 49.35496982510762
# 1123 49.35496982510762
# 1124 49.35496982510762
# 1125 49.35496982510762
# 1126 49.35496982510762
# 1127 49.35496982510762
# 1128 49.35496982510762
# 1129 49.35496982510762
# 1130 49.35496982510762
# 1131 49.35496982510762
# 1132 49.35496982510762
# 1133 49.35496982510762
# 1134 49.35496982510762
# 1135 49.35496982510762
# 1136 49.35496982510762
# 1137 49.35496982510762
# 1138 49.35496982510762
# 1139 49.35496982510762
# 1140 49.35496982510762
# 1141 49.35496982510762
# 1142 49.35496982510762
# 1143 49.35496982510762
# 1144 49.35496982510762
# 1145 49.35496982510762
# 1146 49.35496982510762
# 1147 49.35496982510762
# 1148 49.35496982510762
# 1149 49.35496982510762
# 1150 49.35496982510762
# 1151 49.35496982510762
# 1152 49.35496982510762
# 1153 49.35496982510762
# 1154 49.35496982510762
# 1155 49.35496982510762
# 1156 49.35496982510762
# 1157 49.35496982510762
# 1158 49.35496982510762
# 1159 49.35496982510762
# 1160 49.35496982510762
# 1161 49.35496982510762
# 1162 49.35496982510762
# 1163 49.35496982510762
# 1164 49.35496982510762
# 1165 49.35496982510762
# 1166 49.35496982510762
# 1167 49.35496982510762
# 1168 49.35496982510762
# 1169 49.35496982510762
# 1170 49.35496982510762
# 1171 49.35496982510762
# 1172 49.35496982510762
# 1173 49.35496982510762
# 1174 49.35496982510762
# 1175 49.35496982510762
# 1176 49.35496982510762
# 1177 49.35496982510762
# 1178 49.35496982510762
# 1179 49.35496982510762
# 1180 49.35496982510762
# 1181 49.35496982510762
# 1182 49.35496982510762
# 1183 49.35496982510762
# 1184 49.35496982510762
# 1185 49.35496982510762
# 1186 49.35496982510762
# 1187 49.35496982510762
# 1188 49.35496982510762
# 1189 49.35496982510762
# 1190 49.35496982510762
# 1191 49.35496982510762
# 1192 49.35496982510762
# 1193 49.35496982510762
# 1194 49.35496982510762
# 1195 49.35496982510762
# 1196 49.35496982510762
# 1197 49.35496982510762
# 1198 49.35496982510762
# 1199 49.35496982510762
# 1200 49.35496982510762
# 1201 49.35496982510762
# 1202 49.35496982510762
# 1203 49.35496982510762
# 1204 49.35496982510762
# 1205 49.35496982510762
# 1206 49.35496982510762
# 1207 49.35496982510762
# 1208 49.35496982510762
# 1209 49.35496982510762
# 1210 49.35496982510762
# 1211 49.35496982510762
# 1212 49.35496982510762
# 1213 49.35496982510762
# 1214 49.35496982510762
# 1215 49.35496982510762
# 1216 49.35496982510762
# 1217 49.35496982510762
# 1218 49.35496982510762
# 1219 49.35496982510762
# 1220 49.35496982510762
# 1221 49.35496982510762
# 1222 49.35496982510762
# 1223 49.35496982510762
# 1224 49.35496982510762
# 1225 49.35496982510762
# 1226 49.35496982510762
# 1227 49.35496982510762
# 1228 49.35496982510762
# 1229 49.35496982510762
# 1230 49.35496982510762
# 1231 49.35496982510762
# 1232 49.35496982510762
# 1233 49.35496982510762
# 1234 49.35496982510762
# 1235 49.35496982510762
# 1236 49.35496982510762
# 1237 49.35496982510762
# 1238 49.35496982510762
# 1239 49.35496982510762
# 1240 49.35496982510762
# 1241 49.35496982510762
# 1242 49.35496982510762
# 1243 49.35496982510762
# 1244 49.35496982510762
# 1245 49.35496982510762
# 1246 49.35496982510762
# 1247 49.35496982510762
# 1248 49.35496982510762
# 1249 49.35496982510762
# 1250 49.35496982510762
# 1251 49.35496982510762
# 1252 49.35496982510762
# 1253 49.35496982510762
# 1254 49.35496982510762
# 1255 49.35496982510762
# 1256 49.35496982510762
# 1257 49.35496982510762
# 1258 49.35496982510762
# 1259 49.35496982510762
# 1260 49.35496982510762
# 1261 49.35496982510762
# 1262 49.35496982510762
# 1263 49.35496982510762
# 1264 49.35496982510762
# 1265 49.35496982510762
# 1266 49.35496982510762
# 1267 49.35496982510762
# 1268 49.35496982510762
# 1269 49.35496982510762
# 1270 49.35496982510762
# 1271 49.35496982510762
# 1272 49.35496982510762
# 1273 49.35496982510762
# 1274 49.35496982510762
# 1275 49.35496982510762
# 1276 49.35496982510762
# 1277 49.35496982510762
# 1278 49.35496982510762
# 1279 49.35496982510762
# 1280 49.35496982510762
# 1281 49.35496982510762
# 1282 49.35496982510762
# 1283 49.35496982510762
# 1284 49.35496982510762
# 1285 49.35496982510762
# 1286 49.35496982510762
# 1287 49.35496982510762
# 1288 49.35496982510762
# 1289 49.35496982510762
# 1290 49.35496982510762
# 1291 49.35496982510762
# 1292 49.35496982510762
# 1293 49.35496982510762
# 1294 49.35496982510762
# 1295 49.35496982510762
# 1296 49.35496982510762
# 1297 49.35496982510762
# 1298 49.35496982510762
# 1299 49.35496982510762
# 1300 49.35496982510762
# 1301 49.35496982510762
# 1302 49.35496982510762
# 1303 49.35496982510762
# 1304 49.35496982510762
# 1305 49.35496982510762
# 1306 49.35496982510762
# 1307 49.35496982510762
# 1308 49.35496982510762
# 1309 49.35496982510762
# 1310 49.35496982510762
# 1311 49.35496982510762
# 1312 49.35496982510762
# 1313 49.35496982510762
# 1314 49.35496982510762
# 1315 49.35496982510762
# 1316 49.35496982510762
# 1317 49.35496982510762
# 1318 49.35496982510762
# 1319 49.35496982510762
# 1320 49.35496982510762
# 1321 49.35496982510762
# 1322 49.35496982510762
# 1323 49.35496982510762
# 1324 49.35496982510762
# 1325 49.35496982510762
# 1326 49.35496982510762
# 1327 49.35496982510762
# 1328 49.35496982510762
# 1329 49.35496982510762
# 1330 49.35496982510762
# 1331 49.35496982510762
# 1332 49.35496982510762
# 1333 49.35496982510762
# 1334 49.35496982510762
# 1335 49.35496982510762
# 1336 49.35496982510762
# 1337 49.35496982510762
# 1338 49.35496982510762
# 1339 49.35496982510762
# 1340 49.35496982510762
# 1341 49.35496982510762
# 1342 49.35496982510762
# 1343 49.35496982510762
# 1344 49.35496982510762
# 1345 49.35496982510762
# 1346 49.35496982510762
# 1347 49.35496982510762
# 1348 49.35496982510762
# 1349 49.35496982510762
# 1350 49.35496982510762
# 1351 49.35496982510762
# 1352 49.35496982510762
# 1353 49.35496982510762
# 1354 49.35496982510762
# 1355 49.35496982510762
# 1356 49.35496982510762
# 1357 49.35496982510762
# 1358 49.35496982510762
# 1359 49.35496982510762
# 1360 49.35496982510762
# 1361 49.35496982510762
# 1362 49.35496982510762
# 1363 49.35496982510762
# 1364 49.35496982510762
# 1365 49.35496982510762
# 1366 49.35496982510762
# 1367 49.35496982510762
# 1368 49.35496982510762
# 1369 49.35496982510762
# 1370 49.35496982510762
# 1371 49.35496982510762
# 1372 49.35496982510762
# 1373 49.35496982510762
# 1374 49.35496982510762
# 1375 49.35496982510762
# 1376 49.35496982510762
# 1377 49.35496982510762
# 1378 49.35496982510762
# 1379 49.35496982510762
# 1380 49.35496982510762
# 1381 49.35496982510762
# 1382 49.35496982510762
# 1383 49.35496982510762
# 1384 49.35496982510762
# 1385 49.35496982510762
# 1386 49.35496982510762
# 1387 49.35496982510762
# 1388 49.35496982510762
# 1389 49.35496982510762
# 1390 49.35496982510762
# 1391 49.35496982510762
# 1392 49.35496982510762
# 1393 49.35496982510762
# 1394 49.35496982510762
# 1395 49.35496982510762
# 1396 49.35496982510762
# 1397 49.35496982510762
# 1398 49.35496982510762
# 1399 49.35496982510762
# 1400 49.35496982510762
# 1401 49.35496982510762
# 1402 49.35496982510762
# 1403 49.35496982510762
# 1404 49.35496982510762
# 1405 49.35496982510762
# 1406 49.35496982510762
# 1407 49.35496982510762
# 1408 49.35496982510762
# 1409 49.35496982510762
# 1410 49.35496982510762
# 1411 49.35496982510762
# 1412 49.35496982510762
# 1413 49.35496982510762
# 1414 49.35496982510762
# 1415 49.35496982510762
# 1416 49.35496982510762
# 1417 49.35496982510762
# 1418 49.35496982510762
# 1419 49.35496982510762
# 1420 49.35496982510762
# 1421 49.35496982510762
# 1422 49.35496982510762
# 1423 49.35496982510762
# 1424 49.35496982510762
# 1425 49.35496982510762
# 1426 49.35496982510762
# 1427 49.35496982510762
# 1428 49.35496982510762
# 1429 49.35496982510762
# 1430 49.35496982510762
# 1431 49.35496982510762
# 1432 49.35496982510762
# 1433 49.35496982510762
# 1434 49.35496982510762
# 1435 49.35496982510762
# 1436 49.35496982510762
# 1437 49.35496982510762
# 1438 49.35496982510762
# 1439 49.35496982510762
# 1440 49.35496982510762
# 1441 49.35496982510762
# 1442 49.35496982510762
# 1443 49.35496982510762
# 1444 49.35496982510762
# 1445 49.35496982510762
# 1446 49.35496982510762
# 1447 49.35496982510762
# 1448 49.35496982510762
# 1449 49.35496982510762
# 1450 49.35496982510762
# 1451 49.35496982510762
# 1452 49.35496982510762
# 1453 49.35496982510762
# 1454 49.35496982510762
# 1455 49.35496982510762
# 1456 49.35496982510762
# 1457 49.35496982510762
# 1458 49.35496982510762
# 1459 49.35496982510762
# 1460 49.35496982510762
# 1461 49.35496982510762
# 1462 49.35496982510762
# 1463 49.35496982510762
# 1464 49.35496982510762
# 1465 49.35496982510762
# 1466 49.35496982510762
# 1467 49.35496982510762
# 1468 49.35496982510762
# 1469 49.35496982510762
# 1470 49.35496982510762
# 1471 49.35496982510762
# 1472 49.35496982510762
# 1473 49.35496982510762
# 1474 49.35496982510762
# 1475 49.35496982510762
# 1476 49.35496982510762
# 1477 49.35496982510762
# 1478 49.35496982510762
# 1479 49.35496982510762
# 1480 49.35496982510762
# 1481 49.35496982510762
# 1482 49.35496982510762
# 1483 49.35496982510762
# 1484 49.35496982510762
# 1485 49.35496982510762
# 1486 49.35496982510762
# 1487 49.35496982510762
# 1488 49.35496982510762
# 1489 49.35496982510762
# 1490 49.35496982510762
# 1491 49.35496982510762
# 1492 49.35496982510762
# 1493 49.35496982510762
# 1494 49.35496982510762
# 1495 49.35496982510762
# 1496 49.35496982510762
# 1497 49.35496982510762
# 1498 49.35496982510762
# 1499 49.35496982510762
# 1500 49.35496982510762
# 1501 49.35496982510762
# 1502 49.35496982510762
# 1503 49.35496982510762
# 1504 49.35496982510762
# 1505 49.35496982510762
# 1506 49.35496982510762
# 1507 49.35496982510762
# 1508 49.35496982510762
# 1509 49.35496982510762
# 1510 49.35496982510762
# 1511 49.35496982510762
# 1512 49.35496982510762
# 1513 49.35496982510762
# 1514 49.35496982510762
# 1515 49.35496982510762
# 1516 49.35496982510762
# 1517 49.35496982510762
# 1518 49.35496982510762
# 1519 49.35496982510762
# 1520 49.35496982510762
# 1521 49.35496982510762
# 1522 49.35496982510762
# 1523 49.35496982510762
# 1524 49.35496982510762
# 1525 49.35496982510762
# 1526 49.35496982510762
# 1527 49.35496982510762
# 1528 49.35496982510762
# 1529 49.35496982510762
# 1530 49.35496982510762
# 1531 49.35496982510762
# 1532 49.35496982510762
# 1533 49.35496982510762
# 1534 49.35496982510762
# 1535 49.35496982510762
# 1536 49.35496982510762
# 1537 49.35496982510762
# 1538 49.35496982510762
# 1539 49.35496982510762
# 1540 49.35496982510762
# 1541 49.35496982510762
# 1542 49.35496982510762
# 1543 49.35496982510762
# 1544 49.35496982510762
# 1545 49.35496982510762
# 1546 49.35496982510762
# 1547 49.35496982510762
# 1548 49.35496982510762
# 1549 49.35496982510762
# 1550 49.35496982510762
# 1551 49.35496982510762
# 1552 49.35496982510762
# 1553 49.35496982510762
# 1554 49.35496982510762
# 1555 49.35496982510762
# 1556 49.35496982510762
# 1557 49.35496982510762
# 1558 49.35496982510762
# 1559 49.35496982510762
# 1560 49.35496982510762
# 1561 49.35496982510762
# 1562 49.35496982510762
# 1563 49.35496982510762
# 1564 49.35496982510762
# 1565 49.35496982510762
# 1566 49.35496982510762
# 1567 49.35496982510762
# 1568 49.35496982510762
# 1569 49.35496982510762
# 1570 49.35496982510762
# 1571 49.35496982510762
# 1572 49.35496982510762
# 1573 49.35496982510762
# 1574 49.35496982510762
# 1575 49.35496982510762
# 1576 49.35496982510762
# 1577 49.35496982510762
# 1578 49.35496982510762
# 1579 49.35496982510762
# 1580 49.35496982510762
# 1581 49.35496982510762
# 1582 49.35496982510762
# 1583 49.35496982510762
# 1584 49.35496982510762
# 1585 49.35496982510762
# 1586 49.35496982510762
# 1587 49.35496982510762
# 1588 49.35496982510762
# 1589 49.35496982510762
# 1590 49.35496982510762
# 1591 49.35496982510762
# 1592 49.35496982510762
# 1593 49.35496982510762
# 1594 49.35496982510762
# 1595 49.35496982510762
# 1596 49.35496982510762
# 1597 49.35496982510762
# 1598 49.35496982510762
# 1599 49.35496982510762
# 1600 49.35496982510762
# 1601 49.35496982510762
# 1602 49.35496982510762
# 1603 49.35496982510762
# 1604 49.35496982510762
# 1605 49.35496982510762
# 1606 49.35496982510762
# 1607 49.35496982510762
# 1608 49.35496982510762
# 1609 49.35496982510762
# 1610 49.35496982510762
# 1611 49.35496982510762
# 1612 49.35496982510762
# 1613 49.35496982510762
# 1614 49.35496982510762
# 1615 49.35496982510762
# 1616 49.35496982510762
# 1617 49.35496982510762
# 1618 49.35496982510762
# 1619 49.35496982510762
# 1620 49.35496982510762
# 1621 49.35496982510762
# 1622 49.35496982510762
# 1623 49.35496982510762
# 1624 49.35496982510762
# 1625 49.35496982510762
# 1626 49.35496982510762
# 1627 49.35496982510762
# 1628 49.35496982510762
# 1629 49.35496982510762
# 1630 49.35496982510762
# 1631 49.35496982510762
# 1632 49.35496982510762
# 1633 49.35496982510762
# 1634 49.35496982510762
# 1635 49.35496982510762
# 1636 49.35496982510762
# 1637 49.35496982510762
# 1638 49.35496982510762
# 1639 49.35496982510762
# 1640 49.35496982510762
# 1641 49.35496982510762
# 1642 49.35496982510762
# 1643 49.35496982510762
# 1644 49.35496982510762
# 1645 49.35496982510762
# 1646 49.35496982510762
# 1647 49.35496982510762
# 1648 49.35496982510762
# 1649 49.35496982510762
# 1650 49.35496982510762
# 1651 49.35496982510762
# 1652 49.35496982510762
# 1653 49.35496982510762
# 1654 49.35496982510762
# 1655 49.35496982510762
# 1656 49.35496982510762
# 1657 49.35496982510762
# 1658 49.35496982510762
# 1659 49.35496982510762
# 1660 49.35496982510762
# 1661 49.35496982510762
# 1662 49.35496982510762
# 1663 49.35496982510762
# 1664 49.35496982510762
# 1665 49.35496982510762
# 1666 49.35496982510762
# 1667 49.35496982510762
# 1668 49.35496982510762
# 1669 49.35496982510762
# 1670 49.35496982510762
# 1671 49.35496982510762
# 1672 49.35496982510762
# 1673 49.35496982510762
# 1674 49.35496982510762
# 1675 49.35496982510762
# 1676 49.35496982510762
# 1677 49.35496982510762
# 1678 49.35496982510762
# 1679 49.35496982510762
# 1680 49.35496982510762
# 1681 49.35496982510762
# 1682 49.35496982510762
# 1683 49.35496982510762
# 1684 49.35496982510762
# 1685 49.35496982510762
# 1686 49.35496982510762
# 1687 49.35496982510762
# 1688 49.35496982510762
# 1689 49.35496982510762
# 1690 49.35496982510762
# 1691 49.35496982510762
# 1692 49.35496982510762
# 1693 49.35496982510762
# 1694 49.35496982510762
# 1695 49.35496982510762
# 1696 49.35496982510762
# 1697 49.35496982510762
# 1698 49.35496982510762
# 1699 49.35496982510762
# 1700 49.35496982510762
# 1701 49.35496982510762
# 1702 49.35496982510762
# 1703 49.35496982510762
# 1704 49.35496982510762
# 1705 49.35496982510762
# 1706 49.35496982510762
# 1707 49.35496982510762
# 1708 49.35496982510762
# 1709 49.35496982510762
# 1710 49.35496982510762
# 1711 49.35496982510762
# 1712 49.35496982510762
# 1713 49.35496982510762
# 1714 49.35496982510762
# 1715 49.35496982510762
# 1716 49.35496982510762
# 1717 49.35496982510762
# 1718 49.35496982510762
# 1719 49.35496982510762
# 1720 49.35496982510762
# 1721 49.35496982510762
# 1722 49.35496982510762
# 1723 49.35496982510762
# 1724 49.35496982510762
# 1725 49.35496982510762
# 1726 49.35496982510762
# 1727 49.35496982510762
# 1728 49.35496982510762
# 1729 49.35496982510762
# 1730 49.35496982510762
# 1731 49.35496982510762
# 1732 49.35496982510762
# 1733 49.35496982510762
# 1734 49.35496982510762
# 1735 49.35496982510762
# 1736 49.35496982510762
# 1737 49.35496982510762
# 1738 49.35496982510762
# 1739 49.35496982510762
# 1740 49.35496982510762
# 1741 49.35496982510762
# 1742 49.35496982510762
# 1743 49.35496982510762
# 1744 49.35496982510762
# 1745 49.35496982510762
# 1746 49.35496982510762
# 1747 49.35496982510762
# 1748 49.35496982510762
# 1749 49.35496982510762
# 1750 49.35496982510762
# 1751 49.35496982510762
# 1752 49.35496982510762
# 1753 49.35496982510762
# 1754 49.35496982510762
# 1755 49.35496982510762
# 1756 49.35496982510762
# 1757 49.35496982510762
# 1758 49.35496982510762
# 1759 49.35496982510762
# 1760 49.35496982510762
# 1761 49.35496982510762
# 1762 49.35496982510762
# 1763 49.35496982510762
# 1764 49.35496982510762
# 1765 49.35496982510762
# 1766 49.35496982510762
# 1767 49.35496982510762
# 1768 49.35496982510762
# 1769 49.35496982510762
# 1770 49.35496982510762
# 1771 49.35496982510762
# 1772 49.35496982510762
# 1773 49.35496982510762
# 1774 49.35496982510762
# 1775 49.35496982510762
# 1776 49.35496982510762
# 1777 49.35496982510762
# 1778 49.35496982510762
# 1779 49.35496982510762
# 1780 49.35496982510762
# 1781 49.35496982510762
# 1782 49.35496982510762
# 1783 49.35496982510762
# 1784 49.35496982510762
# 1785 49.35496982510762
# 1786 49.35496982510762
# 1787 49.35496982510762
# 1788 49.35496982510762
# 1789 49.35496982510762
# 1790 49.35496982510762
# 1791 49.35496982510762
# 1792 49.35496982510762
# 1793 49.35496982510762
# 1794 49.35496982510762
# 1795 49.35496982510762
# 1796 49.35496982510762
# 1797 49.35496982510762
# 1798 49.35496982510762
# 1799 49.35496982510762
# 1800 49.35496982510762
# 1801 49.35496982510762
# 1802 49.35496982510762
# 1803 49.35496982510762
# 1804 49.35496982510762
# 1805 49.35496982510762
# 1806 49.35496982510762
# 1807 49.35496982510762
# 1808 49.35496982510762
# 1809 49.35496982510762
# 1810 49.35496982510762
# 1811 49.35496982510762
# 1812 49.35496982510762
# 1813 49.35496982510762
# 1814 49.35496982510762
# 1815 49.35496982510762
# 1816 49.35496982510762
# 1817 49.35496982510762
# 1818 49.35496982510762
# 1819 49.35496982510762
# 1820 49.35496982510762
# 1821 49.35496982510762
# 1822 49.35496982510762
# 1823 49.35496982510762
# 1824 49.35496982510762
# 1825 49.35496982510762
# 1826 49.35496982510762
# 1827 49.35496982510762
# 1828 49.35496982510762
# 1829 49.35496982510762
# 1830 49.35496982510762
# 1831 49.35496982510762
# 1832 49.35496982510762
# 1833 49.35496982510762
# 1834 49.35496982510762
# 1835 49.35496982510762
# 1836 49.35496982510762
# 1837 49.35496982510762
# 1838 49.35496982510762
# 1839 49.35496982510762
# 1840 49.35496982510762
# 1841 49.35496982510762
# 1842 49.35496982510762
# 1843 49.35496982510762
# 1844 49.35496982510762
# 1845 49.35496982510762
# 1846 49.35496982510762
# 1847 49.35496982510762
# 1848 49.35496982510762
# 1849 49.35496982510762
# 1850 49.35496982510762
# 1851 49.35496982510762
# 1852 49.35496982510762
# 1853 49.35496982510762
# 1854 49.35496982510762
# 1855 49.35496982510762
# 1856 49.35496982510762
# 1857 49.35496982510762
# 1858 49.35496982510762
# 1859 49.35496982510762
# 1860 49.35496982510762
# 1861 49.35496982510762
# 1862 49.35496982510762
# 1863 49.35496982510762
# 1864 49.35496982510762
# 1865 49.35496982510762
# 1866 49.35496982510762
# 1867 49.35496982510762
# 1868 49.35496982510762
# 1869 49.35496982510762
# 1870 49.35496982510762
# 1871 49.35496982510762
# 1872 49.35496982510762
# 1873 49.35496982510762
# 1874 49.35496982510762
# 1875 49.35496982510762
# 1876 49.35496982510762
# 1877 49.35496982510762
# 1878 49.35496982510762
# 1879 49.35496982510762
# 1880 49.35496982510762
# 1881 49.35496982510762
# 1882 49.35496982510762
# 1883 49.35496982510762
# 1884 49.35496982510762
# 1885 49.35496982510762
# 1886 49.35496982510762
# 1887 49.35496982510762
# 1888 49.35496982510762
# 1889 49.35496982510762
# 1890 49.35496982510762
# 1891 49.35496982510762
# 1892 49.35496982510762
# 1893 49.35496982510762
# 1894 49.35496982510762
# 1895 49.35496982510762
# 1896 49.35496982510762
# 1897 49.35496982510762
# 1898 49.35496982510762
# 1899 49.35496982510762
# 1900 49.35496982510762
# 1901 49.35496982510762
# 1902 49.35496982510762
# 1903 49.35496982510762
# 1904 49.35496982510762
# 1905 49.35496982510762
# 1906 49.35496982510762
# 1907 49.35496982510762
# 1908 49.35496982510762
# 1909 49.35496982510762
# 1910 49.35496982510762
# 1911 49.35496982510762
# 1912 49.35496982510762
# 1913 49.35496982510762
# 1914 49.35496982510762
# 1915 49.35496982510762
# 1916 49.35496982510762
# 1917 49.35496982510762
# 1918 49.35496982510762
# 1919 49.35496982510762
# 1920 49.35496982510762
# 1921 49.35496982510762
# 1922 49.35496982510762
# 1923 49.35496982510762
# 1924 49.35496982510762
# 1925 49.35496982510762
# 1926 49.35496982510762
# 1927 49.35496982510762
# 1928 49.35496982510762
# 1929 49.35496982510762
# 1930 49.35496982510762
# 1931 49.35496982510762
# 1932 49.35496982510762
# 1933 49.35496982510762
# 1934 49.35496982510762
# 1935 49.35496982510762
# 1936 49.35496982510762
# 1937 49.35496982510762
# 1938 49.35496982510762
# 1939 49.35496982510762
# 1940 49.35496982510762
# 1941 49.35496982510762
# 1942 49.35496982510762
# 1943 49.35496982510762
# 1944 49.35496982510762
# 1945 49.35496982510762
# 1946 49.35496982510762
# 1947 49.35496982510762
# 1948 49.35496982510762
# 1949 49.35496982510762
# 1950 49.35496982510762
# 1951 49.35496982510762
# 1952 49.35496982510762
# 1953 49.35496982510762
# 1954 49.35496982510762
# 1955 49.35496982510762
# 1956 49.35496982510762
# 1957 49.35496982510762
# 1958 49.35496982510762
# 1959 49.35496982510762
# 1960 49.35496982510762
# 1961 49.35496982510762
# 1962 49.35496982510762
# 1963 49.35496982510762
# 1964 49.35496982510762
# 1965 49.35496982510762
# 1966 49.35496982510762
# 1967 49.35496982510762
# 1968 49.35496982510762
# 1969 49.35496982510762
# 1970 49.35496982510762
# 1971 49.35496982510762
# 1972 49.35496982510762
# 1973 49.35496982510762
# 1974 49.35496982510762
# 1975 49.35496982510762
# 1976 49.35496982510762
# 1977 49.35496982510762
# 1978 49.35496982510762
# 1979 49.35496982510762
# 1980 49.35496982510762
# 1981 49.35496982510762
# 1982 49.35496982510762
# 1983 49.35496982510762
# 1984 49.35496982510762
# 1985 49.35496982510762
# 1986 49.35496982510762
# 1987 49.35496982510762
# 1988 49.35496982510762
# 1989 49.35496982510762
# 1990 49.35496982510762
# 1991 49.35496982510762
# 1992 49.35496982510762
# 1993 49.35496982510762
# 1994 49.35496982510762
# 1995 49.35496982510762
# 1996 49.35496982510762
# 1997 49.35496982510762
# 1998 49.35496982510762
# 1999 49.35496982510762
# 2000 49.35496982510762
# 2001 49.35496982510762
# 2002 49.35496982510762
# 2003 49.35496982510762
# 2004 49.35496982510762
# 2005 49.35496982510762
# 2006 49.35496982510762
# 2007 49.35496982510762
# 2008 49.35496982510762
# 2009 49.35496982510762
# 2010 49.35496982510762
# 2011 49.35496982510762
# 2012 49.35496982510762
# 2013 49.35496982510762
# 2014 49.35496982510762
# 2015 49.35496982510762
# 2016 49.35496982510762
# 2017 49.35496982510762
# 2018 49.35496982510762
# 2019 49.35496982510762
# 2020 49.35496982510762
# 2021 49.35496982510762
# 2022 49.35496982510762
# 2023 49.35496982510762
# 2024 49.35496982510762
# 2025 49.35496982510762
# 2026 49.35496982510762
# 2027 49.35496982510762
# 2028 49.35496982510762
# 2029 49.35496982510762
# 2030 49.35496982510762
# 2031 49.35496982510762
# 2032 49.35496982510762
# 2033 49.35496982510762
# 2034 49.35496982510762
# 2035 49.35496982510762
# 2036 49.35496982510762
# 2037 49.35496982510762
# 2038 49.35496982510762
# 2039 49.35496982510762
# 2040 49.35496982510762
# 2041 49.35496982510762
# 2042 49.35496982510762
# 2043 49.35496982510762
# 2044 49.35496982510762
# 2045 49.35496982510762
# 2046 49.35496982510762
# 2047 49.35496982510762
# 2048 49.35496982510762
# 2049 49.35496982510762
# 2050 49.35496982510762
# 2051 49.35496982510762
# 2052 49.35496982510762
# 2053 49.35496982510762
# 2054 49.35496982510762
# 2055 49.35496982510762
# 2056 49.35496982510762
# 2057 49.35496982510762
# 2058 49.35496982510762
# 2059 49.35496982510762
# 2060 49.35496982510762
# 2061 49.35496982510762
# 2062 49.35496982510762
# 2063 49.35496982510762
# 2064 49.35496982510762
# 2065 49.35496982510762
# 2066 49.35496982510762
# 2067 49.35496982510762
# 2068 49.35496982510762
# 2069 49.35496982510762
# 2070 49.35496982510762
# 2071 49.35496982510762
# 2072 49.35496982510762
# 2073 49.35496982510762
# 2074 49.35496982510762
# 2075 49.35496982510762
# 2076 49.35496982510762
# 2077 49.35496982510762
# 2078 49.35496982510762
# 2079 49.35496982510762
# 2080 49.35496982510762
# 2081 49.35496982510762
# 2082 49.35496982510762
# 2083 49.35496982510762
# 2084 49.35496982510762
# 2085 49.35496982510762
# 2086 49.35496982510762
# 2087 49.35496982510762
# 2088 49.35496982510762
# 2089 49.35496982510762
# 2090 49.35496982510762
# 2091 49.35496982510762
# 2092 49.35496982510762
# 2093 49.35496982510762
# 2094 49.35496982510762
# 2095 49.35496982510762
# 2096 49.35496982510762
# 2097 49.35496982510762
# 2098 49.35496982510762
# 2099 49.35496982510762
# 2100 49.35496982510762
# 2101 49.35496982510762
# 2102 49.35496982510762
# 2103 49.35496982510762
# 2104 49.35496982510762
# 2105 49.35496982510762
# 2106 49.35496982510762
# 2107 49.35496982510762
# 2108 49.35496982510762
# 2109 49.35496982510762
# 2110 49.35496982510762
# 2111 49.35496982510762
# 2112 49.35496982510762
# 2113 49.35496982510762
# 2114 49.35496982510762
# 2115 49.35496982510762
# 2116 49.35496982510762
# 2117 49.35496982510762
# 2118 49.35496982510762
# 2119 49.35496982510762
# 2120 49.35496982510762
# 2121 49.35496982510762
# 2122 49.35496982510762
# 2123 49.35496982510762
# 2124 49.35496982510762
# 2125 49.35496982510762
# 2126 49.35496982510762
# 2127 49.35496982510762
# 2128 49.35496982510762
# 2129 49.35496982510762
# 2130 49.35496982510762
# 2131 49.35496982510762
# 2132 49.35496982510762
# 2133 49.35496982510762
# ...
# 4305 49.35496982510762
# 4306 49.35496982510762
# 4307 49.35496982510762
# 4308 49.35496982510762
# 4309 49.35496982510762
# 4310 49.35496982510762
# 4311 49.35496982510762
# 4312 49.35496982510762
# 4313 49.35496982510762
# 4314 49.35496982510762
# 4315 49.35496982510762
# 4316 49.35496982510762
# 4317 49.35496982510762
# 4318 49.35496982510762
# 4319 49.35496982510762
# 4320 49.35496982510762
# 4321 49.35496982510762
# 4322 49.35496982510762
# 4323 49.35496982510762
# 4324 49.35496982510762
# 4325 49.35496982510762
# 4326 49.35496982510762
# 4327 49.35496982510762
# 4328 49.35496982510762
# 4329 49.35496982510762
# 4330 49.35496982510762
# 4331 49.35496982510762
# 4332 49.35496982510762
# 4333 49.35496982510762
# 4334 49.35496982510762
# 4335 49.35496982510762
# 4336 49.35496982510762
# 4337 49.35496982510762
# 4338 49.35496982510762
# 4339 49.35496982510762
# 4340 49.35496982510762
# 4341 49.35496982510762
# 4342 49.35496982510762
# 4343 49.35496982510762
# 4344 49.35496982510762
# 4345 49.35496982510762
# 4346 49.35496982510762
# 4347 49.35496982510762
# 4348 49.35496982510762
# 4349 49.35496982510762
# 4350 49.35496982510762
# 4351 49.35496982510762
# 4352 49.35496982510762
# 4353 49.35496982510762
# 4354 49.35496982510762
# 4355 49.35496982510762
# 4356 49.35496982510762
# 4357 49.35496982510762
# 4358 49.35496982510762
# 4359 49.35496982510762
# 4360 49.35496982510762
# 4361 49.35496982510762
# 4362 49.35496982510762
# 4363 49.35496982510762
# 4364 49.35496982510762
# 4365 49.35496982510762
# 4366 49.35496982510762
# 4367 49.35496982510762
# 4368 49.35496982510762
# 4369 49.35496982510762
# 4370 49.35496982510762
# 4371 49.35496982510762
# 4372 49.35496982510762
# 4373 49.35496982510762
# 4374 49.35496982510762
# 4375 49.35496982510762
# 4376 49.35496982510762
# 4377 49.35496982510762
# 4378 49.35496982510762
# 4379 49.35496982510762
# 4380 49.35496982510762
# 4381 49.35496982510762
# 4382 49.35496982510762
# 4383 49.35496982510762
# 4384 49.35496982510762
# 4385 49.35496982510762
# 4386 49.35496982510762
# 4387 49.35496982510762
# 4388 49.35496982510762
# 4389 49.35496982510762
# 4390 49.35496982510762
# 4391 49.35496982510762
# 4392 49.35496982510762
# 4393 49.35496982510762
# 4394 49.35496982510762
# 4395 49.35496982510762
# 4396 49.35496982510762
# 4397 49.35496982510762
# 4398 49.35496982510762
# 4399 49.35496982510762
# 4400 49.35496982510762
# 4401 49.35496982510762
# 4402 49.35496982510762
# 4403 49.35496982510762
# 4404 49.35496982510762
# 4405 49.35496982510762
# 4406 49.35496982510762
# 4407 49.35496982510762
# 4408 49.35496982510762
# 4409 49.35496982510762
# 4410 49.35496982510762
# 4411 49.35496982510762
# 4412 49.35496982510762
# 4413 49.35496982510762
# 4414 49.35496982510762
# 4415 49.35496982510762
# 4416 49.35496982510762
# 4417 49.35496982510762
# 4418 49.35496982510762
# 4419 49.35496982510762
# 4420 49.35496982510762
# 4421 49.35496982510762
# 4422 49.35496982510762
# 4423 49.35496982510762
# 4424 49.35496982510762
# 4425 49.35496982510762
# 4426 49.35496982510762
# 4427 49.35496982510762
# 4428 49.35496982510762
# 4429 49.35496982510762
# 4430 49.35496982510762
# 4431 49.35496982510762
# 4432 49.35496982510762
# 4433 49.35496982510762
# 4434 49.35496982510762
# 4435 49.35496982510762
# 4436 49.35496982510762
# 4437 49.35496982510762
# 4438 49.35496982510762
# 4439 49.35496982510762
# 4440 49.35496982510762
# 4441 49.35496982510762
# 4442 49.35496982510762
# 4443 49.35496982510762
# 4444 49.35496982510762
# 4445 49.35496982510762
# 4446 49.35496982510762
# 4447 49.35496982510762
# 4448 49.35496982510762
# 4449 49.35496982510762
# 4450 49.35496982510762
# 4451 49.35496982510762
# 4452 49.35496982510762
# 4453 49.35496982510762
# 4454 49.35496982510762
# 4455 49.35496982510762
# 4456 49.35496982510762
# 4457 49.35496982510762
# 4458 49.35496982510762
# 4459 49.35496982510762
# 4460 49.35496982510762
# 4461 49.35496982510762
# 4462 49.35496982510762
# 4463 49.35496982510762
# 4464 49.35496982510762
# 4465 49.35496982510762
# 4466 49.35496982510762
# 4467 49.35496982510762
# 4468 49.35496982510762
# 4469 49.35496982510762
# 4470 49.35496982510762
# 4471 49.35496982510762
# 4472 49.35496982510762
# 4473 49.35496982510762
# 4474 49.35496982510762
# 4475 49.35496982510762
# 4476 49.35496982510762
# 4477 49.35496982510762
# 4478 49.35496982510762
# 4479 49.35496982510762
# 4480 49.35496982510762
# 4481 49.35496982510762
# 4482 49.35496982510762
# 4483 49.35496982510762
# 4484 49.35496982510762
# 4485 49.35496982510762
# 4486 49.35496982510762
# 4487 49.35496982510762
# 4488 49.35496982510762
# 4489 49.35496982510762
# 4490 49.35496982510762
# 4491 49.35496982510762
# 4492 49.35496982510762
# 4493 49.35496982510762
# 4494 49.35496982510762
# 4495 49.35496982510762
# 4496 49.35496982510762
# 4497 49.35496982510762
# 4498 49.35496982510762
# 4499 49.35496982510762
# 4500 49.35496982510762
# 4501 49.35496982510762
# 4502 49.35496982510762
# 4503 49.35496982510762
# 4504 49.35496982510762
# 4505 49.35496982510762
# 4506 49.35496982510762
# 4507 49.35496982510762
# 4508 49.35496982510762
# 4509 49.35496982510762
# 4510 49.35496982510762
# 4511 49.35496982510762
# 4512 49.35496982510762
# 4513 49.35496982510762
# 4514 49.35496982510762
# 4515 49.35496982510762
# 4516 49.35496982510762
# 4517 49.35496982510762
# 4518 49.35496982510762
# 4519 49.35496982510762
# 4520 49.35496982510762
# 4521 49.35496982510762
# 4522 49.35496982510762
# 4523 49.35496982510762
# 4524 49.35496982510762
# 4525 49.35496982510762
# 4526 49.35496982510762
# 4527 49.35496982510762
# 4528 49.35496982510762
# 4529 49.35496982510762
# 4530 49.35496982510762
# 4531 49.35496982510762
# 4532 49.35496982510762
# 4533 49.35496982510762
# 4534 49.35496982510762
# 4535 49.35496982510762
# 4536 49.35496982510762
# 4537 49.35496982510762
# 4538 49.35496982510762
# 4539 49.35496982510762
# 4540 49.35496982510762
# 4541 49.35496982510762
# 4542 49.35496982510762
# 4543 49.35496982510762
# 4544 49.35496982510762
# 4545 49.35496982510762
# 4546 49.35496982510762
# 4547 49.35496982510762
# 4548 49.35496982510762
# 4549 49.35496982510762
# 4550 49.35496982510762
# 4551 49.35496982510762
# 4552 49.35496982510762
# 4553 49.35496982510762
# 4554 49.35496982510762
# 4555 49.35496982510762
# 4556 49.35496982510762
# 4557 49.35496982510762
# 4558 49.35496982510762
# 4559 49.35496982510762
# 4560 49.35496982510762
# 4561 49.35496982510762
# 4562 49.35496982510762
# 4563 49.35496982510762
# 4564 49.35496982510762
# 4565 49.35496982510762
# 4566 49.35496982510762
# 4567 49.35496982510762
# 4568 49.35496982510762
# 4569 49.35496982510762
# 4570 49.35496982510762
# 4571 49.35496982510762
# 4572 49.35496982510762
# 4573 49.35496982510762
# 4574 49.35496982510762
# 4575 49.35496982510762
# 4576 49.35496982510762
# 4577 49.35496982510762
# 4578 49.35496982510762
# 4579 49.35496982510762
# 4580 49.35496982510762
# 4581 49.35496982510762
# 4582 49.35496982510762
# 4583 49.35496982510762
# 4584 49.35496982510762
# 4585 49.35496982510762
# 4586 49.35496982510762
# 4587 49.35496982510762
# 4588 49.35496982510762
# 4589 49.35496982510762
# 4590 49.35496982510762
# 4591 49.35496982510762
# 4592 49.35496982510762
# 4593 49.35496982510762
# 4594 49.35496982510762
# 4595 49.35496982510762
# 4596 49.35496982510762
# 4597 49.35496982510762
# 4598 49.35496982510762
# 4599 49.35496982510762
# 4600 49.35496982510762
# 4601 49.35496982510762
# 4602 49.35496982510762
# 4603 49.35496982510762
# 4604 49.35496982510762
# 4605 49.35496982510762
# 4606 49.35496982510762
# 4607 49.35496982510762
# 4608 49.35496982510762
# 4609 49.35496982510762
# 4610 49.35496982510762
# 4611 49.35496982510762
# 4612 49.35496982510762
# 4613 49.35496982510762
# 4614 49.35496982510762
# 4615 49.35496982510762
# 4616 49.35496982510762
# 4617 49.35496982510762
# 4618 49.35496982510762
# 4619 49.35496982510762
# 4620 49.35496982510762
# 4621 49.35496982510762
# 4622 49.35496982510762
# 4623 49.35496982510762
# 4624 49.35496982510762
# 4625 49.35496982510762
# 4626 49.35496982510762
# 4627 49.35496982510762
# 4628 49.35496982510762
# 4629 49.35496982510762
# 4630 49.35496982510762
# 4631 49.35496982510762
# 4632 49.35496982510762
# 4633 49.35496982510762
# 4634 49.35496982510762
# 4635 49.35496982510762
# 4636 49.35496982510762
# 4637 49.35496982510762
# 4638 49.35496982510762
# 4639 49.35496982510762
# 4640 49.35496982510762
# 4641 49.35496982510762
# 4642 49.35496982510762
# 4643 49.35496982510762
# 4644 49.35496982510762
# 4645 49.35496982510762
# 4646 49.35496982510762
# 4647 49.35496982510762
# 4648 49.35496982510762
# 4649 49.35496982510762
# 4650 49.35496982510762
# 4651 49.35496982510762
# 4652 49.35496982510762
# 4653 49.35496982510762
# 4654 49.35496982510762
# 4655 49.35496982510762
# 4656 49.35496982510762
# 4657 49.35496982510762
# 4658 49.35496982510762
# 4659 49.35496982510762
# 4660 49.35496982510762
# 4661 49.35496982510762
# 4662 49.35496982510762
# 4663 49.35496982510762
# 4664 49.35496982510762
# 4665 49.35496982510762
# 4666 49.35496982510762
# 4667 49.35496982510762
# 4668 49.35496982510762
# 4669 49.35496982510762
# 4670 49.35496982510762
# 4671 49.35496982510762
# 4672 49.35496982510762
# 4673 49.35496982510762
# 4674 49.35496982510762
# 4675 49.35496982510762
# 4676 49.35496982510762
# 4677 49.35496982510762
# 4678 49.35496982510762
# 4679 49.35496982510762
# 4680 49.35496982510762
# 4681 49.35496982510762
# 4682 49.35496982510762
# 4683 49.35496982510762
# 4684 49.35496982510762
# 4685 49.35496982510762
# 4686 49.35496982510762
# 4687 49.35496982510762
# 4688 49.35496982510762
# 4689 49.35496982510762
# 4690 49.35496982510762
# 4691 49.35496982510762
# 4692 49.35496982510762
# 4693 49.35496982510762
# 4694 49.35496982510762
# 4695 49.35496982510762
# 4696 49.35496982510762
# 4697 49.35496982510762
# 4698 49.35496982510762
# 4699 49.35496982510762
# 4700 49.35496982510762
# 4701 49.35496982510762
# 4702 49.35496982510762
# 4703 49.35496982510762
# 4704 49.35496982510762
# 4705 49.35496982510762
# 4706 49.35496982510762
# 4707 49.35496982510762
# 4708 49.35496982510762
# 4709 49.35496982510762
# 4710 49.35496982510762
# 4711 49.35496982510762
# 4712 49.35496982510762
# 4713 49.35496982510762
# 4714 49.35496982510762
# 4715 49.35496982510762
# 4716 49.35496982510762
# 4717 49.35496982510762
# 4718 49.35496982510762
# 4719 49.35496982510762
# 4720 49.35496982510762
# 4721 49.35496982510762
# 4722 49.35496982510762
# 4723 49.35496982510762
# 4724 49.35496982510762
# 4725 49.35496982510762
# 4726 49.35496982510762
# 4727 49.35496982510762
# 4728 49.35496982510762
# 4729 49.35496982510762
# 4730 49.35496982510762
# 4731 49.35496982510762
# 4732 49.35496982510762
# 4733 49.35496982510762
# 4734 49.35496982510762
# 4735 49.35496982510762
# 4736 49.35496982510762
# 4737 49.35496982510762
# 4738 49.35496982510762
# 4739 49.35496982510762
# 4740 49.35496982510762
# 4741 49.35496982510762
# 4742 49.35496982510762
# 4743 49.35496982510762
# 4744 49.35496982510762
# 4745 49.35496982510762
# 4746 49.35496982510762
# 4747 49.35496982510762
# 4748 49.35496982510762
# 4749 49.35496982510762
# 4750 49.35496982510762
# 4751 49.35496982510762
# 4752 49.35496982510762
# 4753 49.35496982510762
# 4754 49.35496982510762
# 4755 49.35496982510762
# 4756 49.35496982510762
# 4757 49.35496982510762
# 4758 49.35496982510762
# 4759 49.35496982510762
# 4760 49.35496982510762
# 4761 49.35496982510762
# 4762 49.35496982510762
# 4763 49.35496982510762
# 4764 49.35496982510762
# 4765 49.35496982510762
# 4766 49.35496982510762
# 4767 49.35496982510762
# 4768 49.35496982510762
# 4769 49.35496982510762
# 4770 49.35496982510762
# 4771 49.35496982510762
# 4772 49.35496982510762
# 4773 49.35496982510762
# 4774 49.35496982510762
# 4775 49.35496982510762
# 4776 49.35496982510762
# 4777 49.35496982510762
# 4778 49.35496982510762
# 4779 49.35496982510762
# 4780 49.35496982510762
# 4781 49.35496982510762
# 4782 49.35496982510762
# 4783 49.35496982510762
# 4784 49.35496982510762
# 4785 49.35496982510762
# 4786 49.35496982510762
# 4787 49.35496982510762
# 4788 49.35496982510762
# 4789 49.35496982510762
# 4790 49.35496982510762
# 4791 49.35496982510762
# 4792 49.35496982510762
# 4793 49.35496982510762
# 4794 49.35496982510762
# 4795 49.35496982510762
# 4796 49.35496982510762
# 4797 49.35496982510762
# 4798 49.35496982510762
# 4799 49.35496982510762
# 4800 49.35496982510762
# 4801 49.35496982510762
# 4802 49.35496982510762
# 4803 49.35496982510762
# 4804 49.35496982510762
# 4805 49.35496982510762
# 4806 49.35496982510762
# 4807 49.35496982510762
# 4808 49.35496982510762
# 4809 49.35496982510762
# 4810 49.35496982510762
# 4811 49.35496982510762
# 4812 49.35496982510762
# 4813 49.35496982510762
# 4814 49.35496982510762
# 4815 49.35496982510762
# 4816 49.35496982510762
# 4817 49.35496982510762
# 4818 49.35496982510762
# 4819 49.35496982510762
# 4820 49.35496982510762
# 4821 49.35496982510762
# 4822 49.35496982510762
# 4823 49.35496982510762
# 4824 49.35496982510762
# 4825 49.35496982510762
# 4826 49.35496982510762
# 4827 49.35496982510762
# 4828 49.35496982510762
# 4829 49.35496982510762
# 4830 49.35496982510762
# 4831 49.35496982510762
# 4832 49.35496982510762
# 4833 49.35496982510762
# 4834 49.35496982510762
# 4835 49.35496982510762
# 4836 49.35496982510762
# 4837 49.35496982510762
# 4838 49.35496982510762
# 4839 49.35496982510762
# 4840 49.35496982510762
# 4841 49.35496982510762
# 4842 49.35496982510762
# 4843 49.35496982510762
# 4844 49.35496982510762
# 4845 49.35496982510762
# 4846 49.35496982510762
# 4847 49.35496982510762
# 4848 49.35496982510762
# 4849 49.35496982510762
# 4850 49.35496982510762
# 4851 49.35496982510762
# 4852 49.35496982510762
# 4853 49.35496982510762
# 4854 49.35496982510762
# 4855 49.35496982510762
# 4856 49.35496982510762
# 4857 49.35496982510762
# 4858 49.35496982510762
# 4859 49.35496982510762
# 4860 49.35496982510762
# 4861 49.35496982510762
# 4862 49.35496982510762
# 4863 49.35496982510762
# 4864 49.35496982510762
# 4865 49.35496982510762
# 4866 49.35496982510762
# 4867 49.35496982510762
# 4868 49.35496982510762
# 4869 49.35496982510762
# 4870 49.35496982510762
# 4871 49.35496982510762
# 4872 49.35496982510762
# 4873 49.35496982510762
# 4874 49.35496982510762
# 4875 49.35496982510762
# 4876 49.35496982510762
# 4877 49.35496982510762
# 4878 49.35496982510762
# 4879 49.35496982510762
# 4880 49.35496982510762
# 4881 49.35496982510762
# 4882 49.35496982510762
# 4883 49.35496982510762
# 4884 49.35496982510762
# 4885 49.35496982510762
# 4886 49.35496982510762
# 4887 49.35496982510762
# 4888 49.35496982510762
# 4889 49.35496982510762
# 4890 49.35496982510762
# 4891 49.35496982510762
# 4892 49.35496982510762
# 4893 49.35496982510762
# 4894 49.35496982510762
# 4895 49.35496982510762
# 4896 49.35496982510762
# 4897 49.35496982510762
# 4898 49.35496982510762
# 4899 49.35496982510762
# 4900 49.35496982510762
# 4901 49.35496982510762
# 4902 49.35496982510762
# 4903 49.35496982510762
# 4904 49.35496982510762
# 4905 49.35496982510762
# 4906 49.35496982510762
# 4907 49.35496982510762
# 4908 49.35496982510762
# 4909 49.35496982510762
# 4910 49.35496982510762
# 4911 49.35496982510762
# 4912 49.35496982510762
# 4913 49.35496982510762
# 4914 49.35496982510762
# 4915 49.35496982510762
# 4916 49.35496982510762
# 4917 49.35496982510762
# 4918 49.35496982510762
# 4919 49.35496982510762
# 4920 49.35496982510762
# 4921 49.35496982510762
# 4922 49.35496982510762
# 4923 49.35496982510762
# 4924 49.35496982510762
# 4925 49.35496982510762
# 4926 49.35496982510762
# 4927 49.35496982510762
# 4928 49.35496982510762
# 4929 49.35496982510762
# 4930 49.35496982510762
# 4931 49.35496982510762
# 4932 49.35496982510762
# 4933 49.35496982510762
# 4934 49.35496982510762
# 4935 49.35496982510762
# 4936 49.35496982510762
# 4937 49.35496982510762
# 4938 49.35496982510762
# 4939 49.35496982510762
# 4940 49.35496982510762
# 4941 49.35496982510762
# 4942 49.35496982510762
# 4943 49.35496982510762
# 4944 49.35496982510762
# 4945 49.35496982510762
# 4946 49.35496982510762
# 4947 49.35496982510762
# 4948 49.35496982510762
# 4949 49.35496982510762
# 4950 49.35496982510762
# 4951 49.35496982510762
# 4952 49.35496982510762
# 4953 49.35496982510762
# 4954 49.35496982510762
# 4955 49.35496982510762
# 4956 49.35496982510762
# 4957 49.35496982510762
# 4958 49.35496982510762
# 4959 49.35496982510762
# 4960 49.35496982510762
# 4961 49.35496982510762
# 4962 49.35496982510762
# 4963 49.35496982510762
# 4964 49.35496982510762
# 4965 49.35496982510762
# 4966 49.35496982510762
# 4967 49.35496982510762
# 4968 49.35496982510762
# 4969 49.35496982510762
# 4970 49.35496982510762
# 4971 49.35496982510762
# 4972 49.35496982510762
# 4973 49.35496982510762
# 4974 49.35496982510762
# 4975 49.35496982510762
# 4976 49.35496982510762
# 4977 49.35496982510762
# 4978 49.35496982510762
# 4979 49.35496982510762
# 4980 49.35496982510762
# 4981 49.35496982510762
# 4982 49.35496982510762
# 4983 49.35496982510762
# 4984 49.35496982510762
# 4985 49.35496982510762
# 4986 49.35496982510762
# 4987 49.35496982510762
# 4988 49.35496982510762
# 4989 49.35496982510762
# 4990 49.35496982510762
# 4991 49.35496982510762
# 4992 49.35496982510762
# 4993 49.35496982510762
# 4994 49.35496982510762
# 4995 49.35496982510762
# 4996 49.35496982510762
# 4997 49.35496982510762
# 4998 49.35496982510762
# 4999 49.35496982510762

# %%
coefs
# Out:
# array([136.82550734])

# %%
plt.scatter(x_train, y_train, label='обучающая выборка')
plt.plot(x_train, f(x_train, coefs), label='предсказанная зависимость')
plt.xlabel('feature')
plt.ylabel('label')
plt.legend()
plt.title('Зависимость целевой переменной от признака')
plt.grid()
plt.show()

# %% [markdown]
# Мы просто аппроксимировали все точки оптимальной константой. Оптимальная константа при минимизации MSE - среднее.

# %%
y_train.mean()
# Out:
# 136.82590354851197

# %% [markdown]
# Модель недообучилась из-за своей неспособности подстроиться под сложные данные. Ситуация, когда модель по каким-то причинам(маленькая выборка, простая модель, недостаточно эпох обучения) не смогла выучить структуру данных **и выдает большую ошибку на обучении** называется **недообучение**.

# %%
coefs = train_f(500, 2, x_train, y_train, 0.1, np.zeros(2)) #0.001 норм
# Out:
# 0 18791.424916621178
# 1 15233.991586696291
# 2 12352.470021860114
# 3 10018.4371322259
# 4 8127.870091467183
# 5 6596.510464474034
# 6 5356.108927044216
# 7 4351.383479366001
# 8 3537.5557080878657
# 9 2878.3550856561087
# 10 2344.402479375527
# 11 1911.9007803919492
# 12 1561.574331581146
# 13 1277.8098542702041
# 14 1047.960582412562
# 15 861.7826314125189
# 16 710.9784636807218
# 17 588.8270618995779
# 18 489.8844075899168
# 19 409.74084122040034
# 20 344.82454059135875
# 21 292.2423270954081
# 22 249.6507260389603
# 23 215.15152141204024
# 24 187.20716047217232
# 25 164.57222466151745
# 26 146.2379224909123
# 27 131.38713448330452
# 28 119.35799450059383
# 29 109.61438859616625
# 30 101.72206592469874
# 31 95.32928371372141
# 32 90.15112876719876
# 33 85.95682254300844
# 34 82.55943390355255
# 35 79.8075487805843
# 36 77.57852140277286
# 37 75.77300849183096
# 38 74.31054276838567
# 39 73.12594535492074
# 40 72.16642134018748
# 41 71.38920671950754
# 42 70.75966284629419
# 43 70.24973217505975
# 44 69.83668835144964
# 45 69.50212255630275
# 46 69.23112457064741
# 47 69.01161616357375
# 48 68.83381399291225
# 49 68.68979416908927
# 50 68.57313831147314
# 51 68.47864712883785
# 52 68.40210929719196
# 53 68.34011346415375
# 54 68.28989683478999
# 55 68.24922134095249
# 56 68.21627411084211
# 57 68.18958679470596
# 58 68.16797012997714
# 59 68.15046058000434
# 60 68.13627785851693
# 61 68.12478985492059
# 62 68.11548457135727
# 63 68.10794725164332
# 64 68.10184207917355
# 65 68.09689686102065
# 66 68.0928912007078
# 67 68.08964663283659
# 68 68.0870185277595
# 69 68.08488977657413
# 70 68.08316546602467
# 71 68.0817687841108
# 72 68.08063745593282
# 73 68.07972098913028
# 74 68.0789787629094
# 75 68.07837755621489
# 76 68.07789055172906
# 77 68.07749611042941
# 78 68.07717660392548
# 79 68.07691780346923
# 80 68.07670817232801
# 81 68.07653837881423
# 82 68.07640077476168
# 83 68.07628938155189
# 84 68.07619915306991
# 85 68.07612605215735
# 86 68.07606686033031
# 87 68.07601891286812
# 88 68.0759800602422
# 89 68.07594857868975
# 90 68.0759231233379
# 91 68.07590253076432
# 92 68.07588581998297
# 93 68.0758722517801
# 94 68.07586126161496
# 95 68.07585239818285
# 96 68.0758452065061
# 97 68.07583948286626
# 98 68.0758347708448
# 99 68.0758309323345
# 100 68.07582785547946
# 101 68.07582533088484
# 102 68.07582334039972
# 103 68.07582168774427
# 104 68.07582039315766
# 105 68.07581933753647
# 106 68.07581848398414
# 107 68.07581779080162
# 108 68.07581722907008
# 109 68.07581677524288
# 110 68.07581640699547
# 111 68.07581610822729
# 112 68.0758158665227
# 113 68.07581567083655
# 114 68.07581551243737
# 115 68.07581538399303
# 116 68.07581527992515
# 117 68.0758151955688
# 118 68.07581512738948
# 119 68.07581507235466
# 120 68.07581502764845
# 121 68.07581499146032
# 122 68.07581496210085
# 123 68.0758149381745
# 124 68.07581491913015
# 125 68.075814903591
# 126 68.07581489094493
# 127 68.07581488067413
# 128 68.07581487241029
# 129 68.07581486575621
# 130 68.07581486032936
# 131 68.07581485592296
# 132 68.075814852304
# 133 68.07581484939548
# 134 68.075814847069
# 135 68.07581484523998
# 136 68.07581484350719
# 137 68.07581484241774
# 138 68.07581484136558
# 139 68.07581484064619
# 140 68.0758148402117
# 141 68.07581483971101
# 142 68.07581483918828
# 143 68.07581483910906
# 144 68.07581483871672
# 145 68.07581483871672
# 146 68.07581483871672
# 147 68.07581483871672
# 148 68.07581483871672
# 149 68.07581483871672
# 150 68.07581483871672
# 151 68.07581483871672
# 152 68.07581483871672
# 153 68.07581483871672
# 154 68.07581483871672
# 155 68.07581483871672
# 156 68.07581483871672
# 157 68.07581483871672
# 158 68.07581483871672
# 159 68.07581483871672
# 160 68.07581483871672
# 161 68.07581483871672
# 162 68.07581483871672
# 163 68.07581483871672
# 164 68.07581483871672
# 165 68.07581483871672
# 166 68.07581483871672
# 167 68.07581483871672
# 168 68.07581483871672
# 169 68.07581483871672
# 170 68.07581483871672
# 171 68.07581483871672
# 172 68.07581483871672
# 173 68.07581483871672
# 174 68.07581483871672
# 175 68.07581483871672
# 176 68.07581483871672
# 177 68.07581483871672
# 178 68.07581483871672
# 179 68.07581483871672
# 180 68.07581483871672
# 181 68.07581483871672
# 182 68.07581483871672
# 183 68.07581483871672
# 184 68.07581483871672
# 185 68.07581483871672
# 186 68.07581483871672
# 187 68.07581483871672
# 188 68.07581483871672
# 189 68.07581483871672
# 190 68.07581483871672
# 191 68.07581483871672
# 192 68.07581483871672
# 193 68.07581483871672
# 194 68.07581483871672
# 195 68.07581483871672
# 196 68.07581483871672
# 197 68.07581483871672
# 198 68.07581483871672
# 199 68.07581483871672
# 200 68.07581483871672
# 201 68.07581483871672
# 202 68.07581483871672
# 203 68.07581483871672
# 204 68.07581483871672
# 205 68.07581483871672
# 206 68.07581483871672
# 207 68.07581483871672
# 208 68.07581483871672
# 209 68.07581483871672
# 210 68.07581483871672
# 211 68.07581483871672
# 212 68.07581483871672
# 213 68.07581483871672
# 214 68.07581483871672
# 215 68.07581483871672
# 216 68.07581483871672
# 217 68.07581483871672
# 218 68.07581483871672
# 219 68.07581483871672
# 220 68.07581483871672
# 221 68.07581483871672
# 222 68.07581483871672
# 223 68.07581483871672
# 224 68.07581483871672
# 225 68.07581483871672
# 226 68.07581483871672
# 227 68.07581483871672
# 228 68.07581483871672
# 229 68.07581483871672
# 230 68.07581483871672
# 231 68.07581483871672
# 232 68.07581483871672
# 233 68.07581483871672
# 234 68.07581483871672
# 235 68.07581483871672
# 236 68.07581483871672
# 237 68.07581483871672
# 238 68.07581483871672
# 239 68.07581483871672
# 240 68.07581483871672
# 241 68.07581483871672
# 242 68.07581483871672
# 243 68.07581483871672
# 244 68.07581483871672
# 245 68.07581483871672
# 246 68.07581483871672
# 247 68.07581483871672
# 248 68.07581483871672
# 249 68.07581483871672
# 250 68.07581483871672
# 251 68.07581483871672
# 252 68.07581483871672
# 253 68.07581483871672
# 254 68.07581483871672
# 255 68.07581483871672
# 256 68.07581483871672
# 257 68.07581483871672
# 258 68.07581483871672
# 259 68.07581483871672
# 260 68.07581483871672
# 261 68.07581483871672
# 262 68.07581483871672
# 263 68.07581483871672
# 264 68.07581483871672
# 265 68.07581483871672
# 266 68.07581483871672
# 267 68.07581483871672
# 268 68.07581483871672
# 269 68.07581483871672
# 270 68.07581483871672
# 271 68.07581483871672
# 272 68.07581483871672
# 273 68.07581483871672
# 274 68.07581483871672
# 275 68.07581483871672
# 276 68.07581483871672
# 277 68.07581483871672
# 278 68.07581483871672
# 279 68.07581483871672
# 280 68.07581483871672
# 281 68.07581483871672
# 282 68.07581483871672
# 283 68.07581483871672
# 284 68.07581483871672
# 285 68.07581483871672
# 286 68.07581483871672
# 287 68.07581483871672
# 288 68.07581483871672
# 289 68.07581483871672
# 290 68.07581483871672
# 291 68.07581483871672
# 292 68.07581483871672
# 293 68.07581483871672
# 294 68.07581483871672
# 295 68.07581483871672
# 296 68.07581483871672
# 297 68.07581483871672
# 298 68.07581483871672
# 299 68.07581483871672
# 300 68.07581483871672
# 301 68.07581483871672
# 302 68.07581483871672
# 303 68.07581483871672
# 304 68.07581483871672
# 305 68.07581483871672
# 306 68.07581483871672
# 307 68.07581483871672
# 308 68.07581483871672
# 309 68.07581483871672
# 310 68.07581483871672
# 311 68.07581483871672
# 312 68.07581483871672
# 313 68.07581483871672
# 314 68.07581483871672
# 315 68.07581483871672
# 316 68.07581483871672
# 317 68.07581483871672
# 318 68.07581483871672
# 319 68.07581483871672
# 320 68.07581483871672
# 321 68.07581483871672
# 322 68.07581483871672
# 323 68.07581483871672
# 324 68.07581483871672
# 325 68.07581483871672
# 326 68.07581483871672
# 327 68.07581483871672
# 328 68.07581483871672
# 329 68.07581483871672
# 330 68.07581483871672
# 331 68.07581483871672
# 332 68.07581483871672
# 333 68.07581483871672
# 334 68.07581483871672
# 335 68.07581483871672
# 336 68.07581483871672
# 337 68.07581483871672
# 338 68.07581483871672
# 339 68.07581483871672
# 340 68.07581483871672
# 341 68.07581483871672
# 342 68.07581483871672
# 343 68.07581483871672
# 344 68.07581483871672
# 345 68.07581483871672
# 346 68.07581483871672
# 347 68.07581483871672
# 348 68.07581483871672
# 349 68.07581483871672
# 350 68.07581483871672
# 351 68.07581483871672
# 352 68.07581483871672
# 353 68.07581483871672
# 354 68.07581483871672
# 355 68.07581483871672
# 356 68.07581483871672
# 357 68.07581483871672
# 358 68.07581483871672
# 359 68.07581483871672
# 360 68.07581483871672
# 361 68.07581483871672
# 362 68.07581483871672
# 363 68.07581483871672
# 364 68.07581483871672
# 365 68.07581483871672
# 366 68.07581483871672
# 367 68.07581483871672
# 368 68.07581483871672
# 369 68.07581483871672
# 370 68.07581483871672
# 371 68.07581483871672
# 372 68.07581483871672
# 373 68.07581483871672
# 374 68.07581483871672
# 375 68.07581483871672
# 376 68.07581483871672
# 377 68.07581483871672
# 378 68.07581483871672
# 379 68.07581483871672
# 380 68.07581483871672
# 381 68.07581483871672
# 382 68.07581483871672
# 383 68.07581483871672
# 384 68.07581483871672
# 385 68.07581483871672
# 386 68.07581483871672
# 387 68.07581483871672
# 388 68.07581483871672
# 389 68.07581483871672
# 390 68.07581483871672
# 391 68.07581483871672
# 392 68.07581483871672
# 393 68.07581483871672
# 394 68.07581483871672
# 395 68.07581483871672
# 396 68.07581483871672
# 397 68.07581483871672
# 398 68.07581483871672
# 399 68.07581483871672
# 400 68.07581483871672
# 401 68.07581483871672
# 402 68.07581483871672
# 403 68.07581483871672
# 404 68.07581483871672
# 405 68.07581483871672
# 406 68.07581483871672
# 407 68.07581483871672
# 408 68.07581483871672
# 409 68.07581483871672
# 410 68.07581483871672
# 411 68.07581483871672
# 412 68.07581483871672
# 413 68.07581483871672
# 414 68.07581483871672
# 415 68.07581483871672
# 416 68.07581483871672
# 417 68.07581483871672
# 418 68.07581483871672
# 419 68.07581483871672
# 420 68.07581483871672
# 421 68.07581483871672
# 422 68.07581483871672
# 423 68.07581483871672
# 424 68.07581483871672
# 425 68.07581483871672
# 426 68.07581483871672
# 427 68.07581483871672
# 428 68.07581483871672
# 429 68.07581483871672
# 430 68.07581483871672
# 431 68.07581483871672
# 432 68.07581483871672
# 433 68.07581483871672
# 434 68.07581483871672
# 435 68.07581483871672
# 436 68.07581483871672
# 437 68.07581483871672
# 438 68.07581483871672
# 439 68.07581483871672
# 440 68.07581483871672
# 441 68.07581483871672
# 442 68.07581483871672
# 443 68.07581483871672
# 444 68.07581483871672
# 445 68.07581483871672
# 446 68.07581483871672
# 447 68.07581483871672
# 448 68.07581483871672
# 449 68.07581483871672
# 450 68.07581483871672
# 451 68.07581483871672
# 452 68.07581483871672
# 453 68.07581483871672
# 454 68.07581483871672
# 455 68.07581483871672
# 456 68.07581483871672
# 457 68.07581483871672
# 458 68.07581483871672
# 459 68.07581483871672
# 460 68.07581483871672
# 461 68.07581483871672
# 462 68.07581483871672
# 463 68.07581483871672
# 464 68.07581483871672
# 465 68.07581483871672
# 466 68.07581483871672
# 467 68.07581483871672
# 468 68.07581483871672
# 469 68.07581483871672
# 470 68.07581483871672
# 471 68.07581483871672
# 472 68.07581483871672
# 473 68.07581483871672
# 474 68.07581483871672
# 475 68.07581483871672
# 476 68.07581483871672
# 477 68.07581483871672
# 478 68.07581483871672
# 479 68.07581483871672
# 480 68.07581483871672
# 481 68.07581483871672
# 482 68.07581483871672
# 483 68.07581483871672
# 484 68.07581483871672
# 485 68.07581483871672
# 486 68.07581483871672
# 487 68.07581483871672
# 488 68.07581483871672
# 489 68.07581483871672
# 490 68.07581483871672
# 491 68.07581483871672
# 492 68.07581483871672
# 493 68.07581483871672
# 494 68.07581483871672
# 495 68.07581483871672
# 496 68.07581483871672
# 497 68.07581483871672
# 498 68.07581483871672
# 499 68.07581483871672

# %%
plt.scatter(x_train, y_train, label='обучающая выборка')
plt.plot(x_train, f(x_train, coefs), label='предсказанная зависимость')
plt.xlabel('feature')
plt.ylabel('label')
plt.legend()
plt.title('Зависимость целевой переменной от признака')
plt.grid()
plt.show()

# %%
coefs = train_f(500, 3, x_train, y_train, 0.1, np.zeros(3)) #0.001 норм
# Out:
# 0 18791.424916621178
# 1 15242.826210231122
# 2 12365.843581032106
# 3 10032.918858319976
# 4 8140.800082439478
# 5 6605.907901660451
# 6 5360.583951765323
# 7 4350.051577179598
# 8 3529.9542883807826
# 9 2864.3620019229966
# 10 2324.1576682140494
# 11 1885.7330362119972
# 12 1529.9361193239158
# 13 1241.2224627348123
# 14 1006.9710661955806
# 15 816.9320775838936
# 16 662.7805600329823
# 17 537.7551119267421
# 18 436.36461257982626
# 19 354.15034064511434
# 20 287.4923105691808
# 21 233.45224032914226
# 22 189.64544047883922
# 23 154.1368905478056
# 24 125.3567628870318
# 25 102.03164285913401
# 26 83.12872356564245
# 27 67.81043266882222
# 28 55.39763282735613
# 29 45.33965639919572
# 30 37.19013147192966
# 31 30.587192784387888
# 32 25.237504465907108
# 33 20.90334482228068
# 34 17.39350276656798
# 35 14.549122021583553
# 36 12.275460870250225
# 37 10.429003188863161
# 38 8.908491290124502
# 39 7.6773938405260616
# 40 6.687517128601152
# 41 5.888886849438861
# 42 5.24025366568996
# 43 4.713377949943741
# 44 4.285349782740816
# 45 3.93758047279526
# 46 3.654985557010123
# 47 3.4253224672545577
# 48 3.2386538623978605
# 49 3.0869124793109695
# 50 2.9635483288362168
# 51 2.863242669384243
# 52 2.781675960453811
# 53 2.71533971606655
# 54 2.6613838449539275
# 55 2.6174928325706643
# 56 2.581784361079906
# 57 2.5527312767385837
# 58 2.529089905032231
# 59 2.5098500759291227
# 60 2.4941906938602236
# 61 2.4814369800657077
# 62 2.4710615928372563
# 63 2.462614139529437
# 64 2.4557350927396935
# 65 2.450114180861924
# 66 2.4455532898716483
# 67 2.4418364483944854
# 68 2.438805500112245
# 69 2.4363374981060044
# 70 2.4343220027794277
# 71 2.4326774699953333
# 72 2.4313477017446843
# 73 2.430257430544224
# 74 2.42937585460633
# 75 2.4286559534606282
# 76 2.428069523323686
# 77 2.427594976634819
# 78 2.427206190556102
# 79 2.426890605057983
# 80 2.4266348557404873
# 81 2.4264245272861715
# 82 2.4262536332428435
# 83 2.4261153867882412
# 84 2.4260027661603436
# 85 2.4259107435828744
# 86 2.42585295416724
# 87 2.4258061434469993
# 88 2.425768225387975
# 89 2.425737512008063
# 90 2.425712632633109
# 91 2.4256924801084385
# 92 2.4256761557445223
# 93 2.4256450742355202
# 94 2.425634369261883
# 95 2.4256256983957365
# 96 2.4256186753271938
# 97 2.4256129865464477
# 98 2.425608378271291
# 99 2.425604645822254
# 100 2.4256016224171564
# 101 2.42559917292839
# 102 2.425597189542863
# 103 2.425595582643586
# 104 2.425594280962818
# 105 2.4255783764633545
# 106 2.425565506451197
# 107 2.425554890540207
# 108 2.425546318797518
# 109 2.4255458627772635
# 110 2.4255390216498047
# 111 2.425533603947706
# 112 2.425533348295858
# 113 2.425533152718549
# 114 2.4255329945447013
# 115 2.4255284659543013
# 116 2.4255250384774896
# 117 2.4255222709723103
# 118 2.4255222025785255
# 119 2.425521895163435
# 120 2.4255218507557585
# 121 2.4255218147513573
# 122 2.4255217857203246
# 123 2.4255216873047982
# 124 2.4255196045616128
# 125 2.4255195831038887
# 126 2.42551957059174
# 127 2.4255195604341564
# 128 2.425519552196063
# 129 2.4255195455450513
# 130 2.4255195401101672
# 131 2.4255195357375956
# 132 2.425519532224646
# 133 2.4255195293544425
# 134 2.425519527028448
# 135 2.4255195251360333
# 136 2.42551952361038
# 137 2.4255195223745254
# 138 2.4255195213715894
# 139 2.4255195205590745
# 140 2.4255195199007282
# 141 2.4255195157114056
# 142 2.4255195154407168
# 143 2.425519515221443
# 144 2.425519515043593
# 145 2.4255195148997353
# 146 2.4255195147827284
# 147 2.4255195146887063
# 148 2.4255195146107336
# 149 2.425519514549306
# 150 2.425519514499396
# 151 2.4255195144584394
# 152 2.425519514426001
# 153 2.4255195143995825
# 154 2.425519514377976
# 155 2.425519514360273
# 156 2.425519514345902
# 157 2.425519514334225
# 158 2.425519514324886
# 159 2.4255195143173993
# 160 2.425519514311268
# 161 2.42551951430579
# 162 2.425519514301972
# 163 2.4255195142988093
# 164 2.4255195142964094
# 165 2.4255195142943142
# 166 2.425519514292595
# 167 2.4255195142909014
# 168 2.425519514289491
# 169 2.425519514288305
# 170 2.425519514287672
# 171 2.425519514287272
# 172 2.4255195142868757
# 173 2.425519514286629
# 174 2.4255195142863406
# 175 2.425519514286119
# 176 2.42551951428598
# 177 2.425519514285974
# 178 2.425519514285974
# 179 2.425519514285974
# 180 2.425519514285974
# 181 2.425519514285974
# 182 2.425519514285974
# 183 2.425519514285974
# 184 2.425519514285974
# 185 2.425519514285974
# 186 2.425519514285974
# 187 2.425519514285974
# 188 2.425519514285974
# 189 2.425519514285974
# 190 2.425519514285974
# 191 2.425519514285974
# 192 2.425519514285974
# 193 2.425519514285974
# 194 2.425519514285974
# 195 2.425519514285974
# 196 2.425519514285974
# 197 2.425519514285974
# 198 2.425519514285974
# 199 2.425519514285974
# 200 2.425519514285974
# 201 2.425519514285974
# 202 2.425519514285974
# 203 2.425519514285974
# 204 2.425519514285974
# 205 2.425519514285974
# 206 2.425519514285974
# 207 2.425519514285974
# 208 2.425519514285974
# 209 2.425519514285974
# 210 2.425519514285974
# 211 2.425519514285974
# 212 2.425519514285974
# 213 2.425519514285974
# 214 2.425519514285974
# 215 2.425519514285974
# 216 2.425519514285974
# 217 2.425519514285974
# 218 2.425519514285974
# 219 2.425519514285974
# 220 2.425519514285974
# 221 2.425519514285974
# 222 2.425519514285974
# 223 2.425519514285974
# 224 2.425519514285974
# 225 2.425519514285974
# 226 2.425519514285974
# 227 2.425519514285974
# 228 2.425519514285974
# 229 2.425519514285974
# 230 2.425519514285974
# 231 2.425519514285974
# 232 2.425519514285974
# 233 2.425519514285974
# 234 2.425519514285974
# 235 2.425519514285974
# 236 2.425519514285974
# 237 2.425519514285974
# 238 2.425519514285974
# 239 2.425519514285974
# 240 2.425519514285974
# 241 2.425519514285974
# 242 2.425519514285974
# 243 2.425519514285974
# 244 2.425519514285974
# 245 2.425519514285974
# 246 2.425519514285974
# 247 2.425519514285974
# 248 2.425519514285974
# 249 2.425519514285974
# 250 2.425519514285974
# 251 2.425519514285974
# 252 2.425519514285974
# 253 2.425519514285974
# 254 2.425519514285974
# 255 2.425519514285974
# 256 2.425519514285974
# 257 2.425519514285974
# 258 2.425519514285974
# 259 2.425519514285974
# 260 2.425519514285974
# 261 2.425519514285974
# 262 2.425519514285974
# 263 2.425519514285974
# 264 2.425519514285974
# 265 2.425519514285974
# 266 2.425519514285974
# 267 2.425519514285974
# 268 2.425519514285974
# 269 2.425519514285974
# 270 2.425519514285974
# 271 2.425519514285974
# 272 2.425519514285974
# 273 2.425519514285974
# 274 2.425519514285974
# 275 2.425519514285974
# 276 2.425519514285974
# 277 2.425519514285974
# 278 2.425519514285974
# 279 2.425519514285974
# 280 2.425519514285974
# 281 2.425519514285974
# 282 2.425519514285974
# 283 2.425519514285974
# 284 2.425519514285974
# 285 2.425519514285974
# 286 2.425519514285974
# 287 2.425519514285974
# 288 2.425519514285974
# 289 2.425519514285974
# 290 2.425519514285974
# 291 2.425519514285974
# 292 2.425519514285974
# 293 2.425519514285974
# 294 2.425519514285974
# 295 2.425519514285974
# 296 2.425519514285974
# 297 2.425519514285974
# 298 2.425519514285974
# 299 2.425519514285974
# 300 2.425519514285974
# 301 2.425519514285974
# 302 2.425519514285974
# 303 2.425519514285974
# 304 2.425519514285974
# 305 2.425519514285974
# 306 2.425519514285974
# 307 2.425519514285974
# 308 2.425519514285974
# 309 2.425519514285974
# 310 2.425519514285974
# 311 2.425519514285974
# 312 2.425519514285974
# 313 2.425519514285974
# 314 2.425519514285974
# 315 2.425519514285974
# 316 2.425519514285974
# 317 2.425519514285974
# 318 2.425519514285974
# 319 2.425519514285974
# 320 2.425519514285974
# 321 2.425519514285974
# 322 2.425519514285974
# 323 2.425519514285974
# 324 2.425519514285974
# 325 2.425519514285974
# 326 2.425519514285974
# 327 2.425519514285974
# 328 2.425519514285974
# 329 2.425519514285974
# 330 2.425519514285974
# 331 2.425519514285974
# 332 2.425519514285974
# 333 2.425519514285974
# 334 2.425519514285974
# 335 2.425519514285974
# 336 2.425519514285974
# 337 2.425519514285974
# 338 2.425519514285974
# 339 2.425519514285974
# 340 2.425519514285974
# 341 2.425519514285974
# 342 2.425519514285974
# 343 2.425519514285974
# 344 2.425519514285974
# 345 2.425519514285974
# 346 2.425519514285974
# 347 2.425519514285974
# 348 2.425519514285974
# 349 2.425519514285974
# 350 2.425519514285974
# 351 2.425519514285974
# 352 2.425519514285974
# 353 2.425519514285974
# 354 2.425519514285974
# 355 2.425519514285974
# 356 2.425519514285974
# 357 2.425519514285974
# 358 2.425519514285974
# 359 2.425519514285974
# 360 2.425519514285974
# 361 2.425519514285974
# 362 2.425519514285974
# 363 2.425519514285974
# 364 2.425519514285974
# 365 2.425519514285974
# 366 2.425519514285974
# 367 2.425519514285974
# 368 2.425519514285974
# 369 2.425519514285974
# 370 2.425519514285974
# 371 2.425519514285974
# 372 2.425519514285974
# 373 2.425519514285974
# 374 2.425519514285974
# 375 2.425519514285974
# 376 2.425519514285974
# 377 2.425519514285974
# 378 2.425519514285974
# 379 2.425519514285974
# 380 2.425519514285974
# 381 2.425519514285974
# 382 2.425519514285974
# 383 2.425519514285974
# 384 2.425519514285974
# 385 2.425519514285974
# 386 2.425519514285974
# 387 2.425519514285974
# 388 2.425519514285974
# 389 2.425519514285974
# 390 2.425519514285974
# 391 2.425519514285974
# 392 2.425519514285974
# 393 2.425519514285974
# 394 2.425519514285974
# 395 2.425519514285974
# 396 2.425519514285974
# 397 2.425519514285974
# 398 2.425519514285974
# 399 2.425519514285974
# 400 2.425519514285974
# 401 2.425519514285974
# 402 2.425519514285974
# 403 2.425519514285974
# 404 2.425519514285974
# 405 2.425519514285974
# 406 2.425519514285974
# 407 2.425519514285974
# 408 2.425519514285974
# 409 2.425519514285974
# 410 2.425519514285974
# 411 2.425519514285974
# 412 2.425519514285974
# 413 2.425519514285974
# 414 2.425519514285974
# 415 2.425519514285974
# 416 2.425519514285974
# 417 2.425519514285974
# 418 2.425519514285974
# 419 2.425519514285974
# 420 2.425519514285974
# 421 2.425519514285974
# 422 2.425519514285974
# 423 2.425519514285974
# 424 2.425519514285974
# 425 2.425519514285974
# 426 2.425519514285974
# 427 2.425519514285974
# 428 2.425519514285974
# 429 2.425519514285974
# 430 2.425519514285974
# 431 2.425519514285974
# 432 2.425519514285974
# 433 2.425519514285974
# 434 2.425519514285974
# 435 2.425519514285974
# 436 2.425519514285974
# 437 2.425519514285974
# 438 2.425519514285974
# 439 2.425519514285974
# 440 2.425519514285974
# 441 2.425519514285974
# 442 2.425519514285974
# 443 2.425519514285974
# 444 2.425519514285974
# 445 2.425519514285974
# 446 2.425519514285974
# 447 2.425519514285974
# 448 2.425519514285974
# 449 2.425519514285974
# 450 2.425519514285974
# 451 2.425519514285974
# 452 2.425519514285974
# 453 2.425519514285974
# 454 2.425519514285974
# 455 2.425519514285974
# 456 2.425519514285974
# 457 2.425519514285974
# 458 2.425519514285974
# 459 2.425519514285974
# 460 2.425519514285974
# 461 2.425519514285974
# 462 2.425519514285974
# 463 2.425519514285974
# 464 2.425519514285974
# 465 2.425519514285974
# 466 2.425519514285974
# 467 2.425519514285974
# 468 2.425519514285974
# 469 2.425519514285974
# 470 2.425519514285974
# 471 2.425519514285974
# 472 2.425519514285974
# 473 2.425519514285974
# 474 2.425519514285974
# 475 2.425519514285974
# 476 2.425519514285974
# 477 2.425519514285974
# 478 2.425519514285974
# 479 2.425519514285974
# 480 2.425519514285974
# 481 2.425519514285974
# 482 2.425519514285974
# 483 2.425519514285974
# 484 2.425519514285974
# 485 2.425519514285974
# 486 2.425519514285974
# 487 2.425519514285974
# 488 2.425519514285974
# 489 2.425519514285974
# 490 2.425519514285974
# 491 2.425519514285974
# 492 2.425519514285974
# 493 2.425519514285974
# 494 2.425519514285974
# 495 2.425519514285974
# 496 2.425519514285974
# 497 2.425519514285974
# 498 2.425519514285974
# 499 2.425519514285974

# %%
plt.scatter(x_train, y_train, label='обучающая выборка')
plt.plot(x_train, f(x_train, coefs), label='предсказанная зависимость')
plt.xlabel('feature')
plt.ylabel('label')
plt.legend()
plt.title('Зависимость целевой переменной от признака')
plt.grid()
plt.show()

# %% [markdown]
# #### **В самый раз!**

# %%
from sklearn.linear_model import LinearRegression # импортируем линейную регрессию
from sklearn.preprocessing import PolynomialFeatures
X_objects = PolynomialFeatures(20).fit_transform(x_train[:, None])
regr = LinearRegression().fit(X_objects, y_train)
NewY = regr.predict(X_objects)

plt.scatter(x_train, y_train, label='обучающая выборка')
plt.plot(x_train, NewY, label='предсказанная зависимость')
plt.xlabel('feature')
plt.ylabel('label')
plt.legend()
plt.title('Зависимость целевой переменной от признака')
plt.grid()
plt.show()

# %%
X = np.linspace(10, 35, 100)
X_objects = PolynomialFeatures(20).fit_transform(X[:, None])
NewY = regr.predict(X_objects)

plt.scatter(x_train, y_train, label='обучающая выборка')
plt.plot(X, NewY, label='предсказанная зависимость')
plt.xlabel('feature')
plt.ylabel('label')
plt.legend()
plt.title('Зависимость целевой переменной от признака')
plt.grid()
plt.show()

# %% [markdown]
# Модель передообучилась из-за своей высокой сложности. Ситуация, когда модель по каким-то причинам(маленькая выборка, сложная модель, слишком много эпох обучения) слишком хорошо подстроилась под обучающую выборку и выдает очень маленькую ошибку на обучении, но не способна сделать верное предсказание на объектах, которые не входили в обучающую выборку называется **переобучение**.

# %% [markdown]
# ## Работа с табличными данными

# %% [markdown]
# Решение любой задачи, связанной с машинным обучением, начинается с разведочного анализа данных. Перед тем, как строить модели, надо понять, сколько у нас данных и какая информация есть о каждом объекте, а также:
# * выяснить, нет ли пропусков в данных (т.е. отсутствующих значений признаков у некоторых объектов)
# * выяснить, нет ли выбросов (т.е. объектов, которые очень сильно отличаются от большинства, имеют неадекватные значения признаков)
# * выяснить, нет ли повторов в данных
# * выяснить, нет ли нелогичной информации (например, если мы анализируем данные по кредитам, и видим запись, где кредит выдали пятилетнему ребёнку, то это странно)
#
# И это лишь небольшой список проблем, которые можно выявить. Помимо этого с данными нужно в целом познакомиться, чтобы понять, какие признаки там можно сделать, какие из них будут наиболее полезны. Обычно 80% времени специалисты тратят именно на подготовку и обработку данных.
#
# Результатом разведочного анализа данных обычно является таблица, где каждый объект описывается набором интуитивно понятных признаков. Поэтому важно уметь работать с таблицами.
#
#
# Попробуем провести разведочный анализ на реальной задаче предсказания продолжительности поездки на такси в Нью-Йорке: https://www.kaggle.com/c/nyc-taxi-trip-duration/overview

# %% [markdown]
# Для работы с таблицами в питоне есть специальная библиотека Pandas. Ее мы и будем использовать.
#
# Полезные материалы по пандасу:
#
# Полезные материалы:
# 1. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html)
# 2. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Чаще всего название библиотеки при импорте сокращают до "pd":

# %%
import pandas as pd

# %% [markdown]
# ### Распределение студентов по элективам

# %% [markdown]
# Разумно тренироваться на реальных сложных данных. А что может быть более сложным, чем данные, сгенерированные студентами?
#
# Сегодня мы будем работать с анкетами студентов ПМИ 2017 и 2018 годов набора о том, на какие курсы по выбору они хотят попасть. Данные были анонимизированы: ФИО захешированы с солью, к рейтингам добавлен случайный шум.
#
# *Вопрос: как можно деанонимизировать данные после манипуляций, которые мы проделали? А как бы вы предложили провести анонимизацию?*

# %% [markdown]
# У нас есть 2 таблицы (для 3 и 4 курса):
#
#     – 'Timestamp': время получения ответов
#     – 'ID': ID студента (может повторяться, если студент больше одного раза заполнял анкету)
#     – 'Рейтинг': Кредитно-рейтинговая сумма студента (грубо говоря, сумма оценок студента по всем его дисциплинам с весами — чем дольша шла дисциплина, тем больше вес; подробности тут: https://www.hse.ru/studyspravka/rate/)
#     – 'Группа (в формате 182)': Номер группы
#     – 'МИ?': 1, если студент распределился на специализацию МИ, или NaN в противном случае (признак важен, поскольку студенты МИ берут осенью два курса по выбору, а студенты остальных специализаций только один)
#     – 'Осенний курс по выбору, приоритет 1'
#     – 'Осенний курс по выбору, приоритет 2'
#     – 'Осенний курс по выбору, приоритет 3'
#     – 'Весенний курс по выбору, приоритет 1'
#     – 'Весенний курс по выбору, приоритет 2'
#     – 'Весенний курс по выбору, приоритет 3'
#     – 'Вы заполняете анкету в первый раз?': "Да" или "Нет"
#
# Дополнительные столбцы для 4ого курса:
#
#     – 'Группа (в формате 173)': Номер группы
#     – 'blended-курс': Выбор blended-курса (кол-во мест неограничено)

# %% [markdown]
# Загрузим данные (обратите внимание, что мы легко читаем xlsx-файлы):

# %%
# !wget  -O 'data_3_course.xlsx' -q 'https://www.dropbox.com/s/ysxs5srafoyxknb/_data_3_course.xlsx?dl=1'
# !wget  -O 'data_4_course.xlsx' -q 'https://www.dropbox.com/s/hfg2mzmvcivtxqk/_data_4_course.xlsx?dl=1'

# %%
data3 = pd.read_excel('data_3_course.xlsx')
data4 = pd.read_excel('data_4_course.xlsx')

# %%
data3
# Out:
#                   Timestamp                                ID Рейтинг  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632,0
# ..                      ...                               ...     ...
# 218 2020-05-20 11:49:38.801  bd416140ecdb32b6dbd7f40820bf63b1   517,0
# 219 2020-05-20 11:57:07.326  e6f5eb76b34e7ab7bac753e6cb0a2279   634,0
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0   584,0
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc   646,0
# 222 2020-05-19 04:24:29.000  9d19b0d5f4fc8d7edc2258406f872c4e   694,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                       181  NaN                            Язык SQL
# 1                       181  NaN   Высокопроизводительные вычисления
# 2                       185  NaN    Безопасность компьютерных систем
# 3                       182  NaN         Statistical Learning Theory
# 4                       183  NaN   Высокопроизводительные вычисления
# ..                      ...  ...                                 ...
# 218                     185  NaN    Безопасность компьютерных систем
# 219                     184  NaN                   Теория баз данных
# 220                     188  NaN                            Язык SQL
# 221                     186  NaN                   Теория баз данных
# 222                     188  NaN    Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0     Высокопроизводительные вычисления                Матричные вычисления
# 1      Безопасность компьютерных систем                            Язык SQL
# 2                  Матричные вычисления       Моделирование временных рядов
# 3     Высокопроизводительные вычисления                Матричные вычисления
# 4      Безопасность компьютерных систем                   Теория баз данных
# ..                                  ...                                 ...
# 218                   Теория баз данных                            Язык SQL
# 219    Безопасность компьютерных систем       Моделирование временных рядов
# 220                   Теория баз данных    Безопасность компьютерных систем
# 221   Высокопроизводительные вычисления    Безопасность компьютерных систем
# 222                            Язык SQL   Высокопроизводительные вычисления
#
#             Весенний курс по выбору, приоритет 1  \
# 0                         Дискретная оптимизация
# 1                         Дискретная оптимизация
# 2                         Дискретная оптимизация
# 3                         Дискретная оптимизация
# 4                              Компьютерные сети
# ..                                           ...
# 218                          Машинное обучение 2
# 219                            Компьютерные сети
# 220  Промышленное программирование на языке Java
# 221                            Компьютерные сети
# 222                            Компьютерные сети
#
#             Весенний курс по выбору, приоритет 2  \
# 0                               Численные методы
# 1                               Численные методы
# 2                            Машинное обучение 2
# 3                               Численные методы
# 4                         Дискретная оптимизация
# ..                                           ...
# 218                            Компьютерные сети
# 219  Промышленное программирование на языке Java
# 220                            Компьютерные сети
# 221                       Дискретная оптимизация
# 222                       Дискретная оптимизация
#
#             Весенний курс по выбору, приоритет 3  \
# 0                            Машинное обучение 2
# 1                            Машинное обучение 2
# 2                               Численные методы
# 3                            Машинное обучение 2
# 4                               Численные методы
# ..                                           ...
# 218  Промышленное программирование на языке Java
# 219                      Анализ данных в бизнесе
# 220                           Системы баз данных
# 221                          Машинное обучение 2
# 222                             Численные методы
#
#     Вы заполняете анкету в первый раз?
# 0                                   Да
# 1                                  Нет
# 2                                   Да
# 3                                   Да
# 4                                   Да
# ..                                 ...
# 218                                 Да
# 219                                 Да
# 220                                 Да
# 221                                Нет
# 222                                NaN
#
# [223 rows x 12 columns]

# %% [markdown]
# Посмотрим размер таблицы:

# %%
data3.shape
# Out:
# (223, 12)

# %% [markdown]
# Для начала будем работать с одной таблицей для 3 курса. Теперь данные хранятся в переменной ```data3```, которая имеет тип [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html):

# %%
type(data3)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# DataFrame можно создать и вручную:

# %%
df = pd.DataFrame({'AAA' : [4,5,6,7],
                   'BBB' : [10,20,30,40],
                   'CCC' : [100,50,'E',-50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30    E
# 3    7   40  -50

# %% [markdown]
# DataFrame можно частично отобразить в jupyter-ноутбуке с помощью методов ```head```(первые строки) и ```sample```(случайные строки):

# %%
data3.tail(2)
# Out:
#                   Timestamp                                ID Рейтинг  \
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc   646,0
# 222 2020-05-19 04:24:29.000  9d19b0d5f4fc8d7edc2258406f872c4e   694,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 221                     186  NaN                   Теория баз данных
# 222                     188  NaN    Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 221   Высокопроизводительные вычисления    Безопасность компьютерных систем
# 222                            Язык SQL   Высокопроизводительные вычисления
#
#     Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 221                    Компьютерные сети               Дискретная оптимизация
# 222                    Компьютерные сети               Дискретная оптимизация
#
#     Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 221                  Машинное обучение 2                                Нет
# 222                     Численные методы                                NaN

# %%
dd = data3.sample(3)

# %%
dd
# Out:
#                   Timestamp                                ID Рейтинг  \
# 68  2020-05-18 12:55:36.645  d61cc836b6aa3cdc4a40e2e8ada0b937   671,0
# 143 2020-05-18 21:36:30.617  2826fc94cd575c8f7b0a2416506e70e5   613,0
# 46  2020-05-17 13:24:57.167  a37a88d97b12fe90dd83dd548866b2bb   706,0
#
#      Группа (в формате 182)  МИ?  \
# 68                      182  NaN
# 143                     185  NaN
# 46                      186  NaN
#
#                  Осенний курс по выбору, приоритет 1  \
# 68                  Безопасность компьютерных систем
# 143                Высокопроизводительные вычисления
# 46   Сбор и обработка данных с помощью краудсорсинга
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 68    Высокопроизводительные вычисления                            Язык SQL
# 143    Безопасность компьютерных систем                   Теория баз данных
# 46     Безопасность компьютерных систем                Матричные вычисления
#
#             Весенний курс по выбору, приоритет 1  \
# 68                             Компьютерные сети
# 143                       Дискретная оптимизация
# 46   Промышленное программирование на языке Java
#
#             Весенний курс по выбору, приоритет 2  \
# 68   Промышленное программирование на языке Java
# 143                          Машинное обучение 2
# 46                             Компьютерные сети
#
#     Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 68                   Машинное обучение 2                                Нет
# 143                    Компьютерные сети                                 Да
# 46                Дискретная оптимизация                                 Да

# %% [markdown]
# Можно немного залезть во внутренности Jupyter, чтобы отобразить сразу несколько таблиц:

# %%
from IPython.display import display
display(data3.sample(3)), display(data3.sample(3))
# Out:
#                   Timestamp                                ID Рейтинг  \
# 75  2020-05-18 16:45:06.205  081eba3952cfc116e0e9b941d6a974a2   692,0
# 172 2020-05-18 22:35:46.073  ddea5295ac96e74f05982e47c7ab4ff4   606,0
# 130 2020-05-18 21:12:29.736  ac4e2062ca444a506991c212bd2dd872   562,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 75                      182  NaN    Безопасность компьютерных систем
# 172                     185  NaN       Моделирование временных рядов
# 130                     187  NaN    Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2  \
# 75                 Матричные вычисления
# 172    Безопасность компьютерных систем
# 130                            Язык SQL
#
#                  Осенний курс по выбору, приоритет 3  \
# 75                                 Теория баз данных
# 172  Сбор и обработка данных с помощью краудсорсинга
# 130                             Матричные вычисления
#
#             Весенний курс по выбору, приоритет 1  \
# 75   Промышленное программирование на языке Java
# 172  Промышленное программирование на языке Java
# 130  Промышленное программирование на языке Java
#
#     Весенний курс по выбору, приоритет 2 Весенний курс по выбору, приоритет 3  \
# 75                Дискретная оптимизация                   Системы баз данных
# 172                  Машинное обучение 2              Анализ данных в бизнесе
# 130              Анализ данных в бизнесе                     Численные методы
#
#     Вы заполняете анкету в первый раз?
# 75                                 Нет
# 172                                 Да
# 130                                Нет
#                   Timestamp                                ID Рейтинг  \
# 172 2020-05-18 22:35:46.073  ddea5295ac96e74f05982e47c7ab4ff4   606,0
# 36  2020-05-16 21:43:04.275  d37fe725a8ee1d1b263463baf7560fd4   750,0
# 145 2020-05-18 21:38:00.271  b3e75ee2a708cef65cc2f80da894dd50   560,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 172                     185  NaN       Моделирование временных рядов
# 36                      184  NaN    Безопасность компьютерных систем
# 145                     187  NaN    Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2  \
# 172    Безопасность компьютерных систем
# 36                    Теория баз данных
# 145       Моделирование временных рядов
#
#                  Осенний курс по выбору, приоритет 3  \
# 172  Сбор и обработка данных с помощью краудсорсинга
# 36                 Высокопроизводительные вычисления
# 145                                         Язык SQL
#
#             Весенний курс по выбору, приоритет 1  \
# 172  Промышленное программирование на языке Java
# 36   Промышленное программирование на языке Java
# 145                      Анализ данных в бизнесе
#
#             Весенний курс по выбору, приоритет 2  \
# 172                          Машинное обучение 2
# 36                             Компьютерные сети
# 145  Промышленное программирование на языке Java
#
#     Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 172              Анализ данных в бизнесе                                 Да
# 36                Дискретная оптимизация                                 Да
# 145                     Численные методы                                 Да
# (None, None)

# %% [markdown]
# Если вам очень хочется отобразить все строки таблицы, то можно сделать так:

# %%
# pd.options.display.max_rows = 999
# data3

# %%
data3
# Out:
#                   Timestamp                                ID Рейтинг  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632,0
# ..                      ...                               ...     ...
# 218 2020-05-20 11:49:38.801  bd416140ecdb32b6dbd7f40820bf63b1   517,0
# 219 2020-05-20 11:57:07.326  e6f5eb76b34e7ab7bac753e6cb0a2279   634,0
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0   584,0
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc   646,0
# 222 2020-05-19 04:24:29.000  9d19b0d5f4fc8d7edc2258406f872c4e   694,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                       181  NaN                            Язык SQL
# 1                       181  NaN   Высокопроизводительные вычисления
# 2                       185  NaN    Безопасность компьютерных систем
# 3                       182  NaN         Statistical Learning Theory
# 4                       183  NaN   Высокопроизводительные вычисления
# ..                      ...  ...                                 ...
# 218                     185  NaN    Безопасность компьютерных систем
# 219                     184  NaN                   Теория баз данных
# 220                     188  NaN                            Язык SQL
# 221                     186  NaN                   Теория баз данных
# 222                     188  NaN    Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0     Высокопроизводительные вычисления                Матричные вычисления
# 1      Безопасность компьютерных систем                            Язык SQL
# 2                  Матричные вычисления       Моделирование временных рядов
# 3     Высокопроизводительные вычисления                Матричные вычисления
# 4      Безопасность компьютерных систем                   Теория баз данных
# ..                                  ...                                 ...
# 218                   Теория баз данных                            Язык SQL
# 219    Безопасность компьютерных систем       Моделирование временных рядов
# 220                   Теория баз данных    Безопасность компьютерных систем
# 221   Высокопроизводительные вычисления    Безопасность компьютерных систем
# 222                            Язык SQL   Высокопроизводительные вычисления
#
#             Весенний курс по выбору, приоритет 1  \
# 0                         Дискретная оптимизация
# 1                         Дискретная оптимизация
# 2                         Дискретная оптимизация
# 3                         Дискретная оптимизация
# 4                              Компьютерные сети
# ..                                           ...
# 218                          Машинное обучение 2
# 219                            Компьютерные сети
# 220  Промышленное программирование на языке Java
# 221                            Компьютерные сети
# 222                            Компьютерные сети
#
#             Весенний курс по выбору, приоритет 2  \
# 0                               Численные методы
# 1                               Численные методы
# 2                            Машинное обучение 2
# 3                               Численные методы
# 4                         Дискретная оптимизация
# ..                                           ...
# 218                            Компьютерные сети
# 219  Промышленное программирование на языке Java
# 220                            Компьютерные сети
# 221                       Дискретная оптимизация
# 222                       Дискретная оптимизация
#
#             Весенний курс по выбору, приоритет 3  \
# 0                            Машинное обучение 2
# 1                            Машинное обучение 2
# 2                               Численные методы
# 3                            Машинное обучение 2
# 4                               Численные методы
# ..                                           ...
# 218  Промышленное программирование на языке Java
# 219                      Анализ данных в бизнесе
# 220                           Системы баз данных
# 221                          Машинное обучение 2
# 222                             Численные методы
#
#     Вы заполняете анкету в первый раз?
# 0                                   Да
# 1                                  Нет
# 2                                   Да
# 3                                   Да
# 4                                   Да
# ..                                 ...
# 218                                 Да
# 219                                 Да
# 220                                 Да
# 221                                Нет
# 222                                NaN
#
# [223 rows x 12 columns]

# %% [markdown]
# DataFrame, по сути, является двумерной таблицей с набором полезных методов. Давайте рассмотрим некоторые из них.
#
# ```columns``` — возвращает названия колонок
#
# ```dtypes``` — типы колонок

# %%
data3.columns
# Out:
# Index(['Timestamp', 'ID', 'Рейтинг', 'Группа (в формате 182)', 'МИ?',
#        'Осенний курс по выбору, приоритет 1',
#        'Осенний курс по выбору, приоритет 2',
#        'Осенний курс по выбору, приоритет 3',
#        'Весенний курс по выбору, приоритет 1',
#        'Весенний курс по выбору, приоритет 2',
#        'Весенний курс по выбору, приоритет 3',
#        'Вы заполняете анкету в первый раз?'],
#       dtype='object')

# %%
data3.dtypes
# Out:
# Timestamp                               datetime64[ns]
# ID                                              object
# Рейтинг                                         object
# Группа (в формате 182)                           int64
# МИ?                                            float64
# Осенний курс по выбору, приоритет 1             object
# Осенний курс по выбору, приоритет 2             object
# Осенний курс по выбору, приоритет 3             object
# Весенний курс по выбору, приоритет 1            object
# Весенний курс по выбору, приоритет 2            object
# Весенний курс по выбору, приоритет 3            object
# Вы заполняете анкету в первый раз?              object
# dtype: object

# %% [markdown]
# В DataFrame есть несколько способов для обращения к строкам, столбцам и отдельным элементам таблицы: квадратные скобки и методы ```loc```, ```iloc```.
#
# Как обычно, лучший источник знаний об этом — [документация](https://pandas.pydata.org/docs/user_guide/indexing.html).
# Ниже краткое содержание.

# %% [markdown]
# В метод ```loc``` можно передать значение индекса (число, которое стоит в колонке index) строки, чтобы получить эту строку:

# %%
#data3[2]

# %%
data3.loc[2]
# Out:
# Timestamp                                     2020-05-15 03:12:41.480000
# ID                                      30f3653fc176d54e89ac3179c455c6dd
# Рейтинг                                                            624,0
# Группа (в формате 182)                                               185
# МИ?                                                                  NaN
# Осенний курс по выбору, приоритет 1     Безопасность компьютерных систем
# Осенний курс по выбору, приоритет 2                 Матричные вычисления
# Осенний курс по выбору, приоритет 3        Моделирование временных рядов
# Весенний курс по выбору, приоритет 1              Дискретная оптимизация
# Весенний курс по выбору, приоритет 2                 Машинное обучение 2
# Весенний курс по выбору, приоритет 3                    Численные методы
# Вы заполняете анкету в первый раз?                                    Да
# Name: 2, dtype: object

# %% [markdown]
# Получили отдельную строчку в виде объекта класса [Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html):

# %%
type(data3.loc[2])
# Out:
# pandas.core.series.Series

# %% [markdown]
# А с помощью срезов можно выбрать часть таблицы:

# %%
data3.loc[2:4]
# Out:
#                 Timestamp                                ID Рейтинг  \
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632,0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
# 4                     183  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
# 4    Безопасность компьютерных систем                   Теория баз данных
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
# 4                    Компьютерные сети               Дискретная оптимизация
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 2                     Численные методы                                 Да
# 3                  Машинное обучение 2                                 Да
# 4                     Численные методы                                 Да

# %% [markdown]
# Срез в ```loc``` производится по index и включает в себя последний элемент.
#
# Метод ```iloc``` действует похожим образом, но он индексирует элементы не по index, а по порядку в таблице (который может отличаться от index). Например:

# %%
subset = data3.sample(5)
subset
# Out:
#                   Timestamp                                ID Рейтинг  \
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 31  2020-05-16 17:44:55.307  7df351e9f3a719f6c29e811e2578fcc6   637,0
# 85  2020-05-18 17:32:12.074  651f2fa7d270b436246ddd7d05880bfa   755,0
# 190 2020-05-18 23:31:33.712  7e844607673355cefa63252f558b69cb   673,0
# 206 2020-05-18 23:59:29.314  f7f123322f77fd451a30ed4979c323fc   595,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 2                       185  NaN    Безопасность компьютерных систем
# 31                      188  NaN    Безопасность компьютерных систем
# 85                      182  NaN                   Теория баз данных
# 190                     181  NaN    Безопасность компьютерных систем
# 206                     185  NaN                            Язык SQL
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 2                  Матричные вычисления       Моделирование временных рядов
# 31    Высокопроизводительные вычисления                            Язык SQL
# 85        Моделирование временных рядов         Statistical Learning Theory
# 190   Высокопроизводительные вычисления                   Теория баз данных
# 206    Безопасность компьютерных систем                   Теория баз данных
#
#             Весенний курс по выбору, приоритет 1  \
# 2                         Дискретная оптимизация
# 31                             Компьютерные сети
# 85    Дополнительные главы прикладной статистики
# 190                            Компьютерные сети
# 206  Промышленное программирование на языке Java
#
#     Весенний курс по выбору, приоритет 2  \
# 2                    Машинное обучение 2
# 31                    Системы баз данных
# 85                      Численные методы
# 190                   Системы баз данных
# 206                    Компьютерные сети
#
#             Весенний курс по выбору, приоритет 3  \
# 2                               Численные методы
# 31                           Машинное обучение 2
# 85                            Системы баз данных
# 190  Промышленное программирование на языке Java
# 206                           Системы баз данных
#
#     Вы заполняете анкету в первый раз?
# 2                                   Да
# 31                                  Да
# 85                                  Да
# 190                                 Да
# 206                                Нет

# %%
subset.loc[2:85]
# Out:
#                  Timestamp                                ID Рейтинг  \
# 2  2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 31 2020-05-16 17:44:55.307  7df351e9f3a719f6c29e811e2578fcc6   637,0
# 85 2020-05-18 17:32:12.074  651f2fa7d270b436246ddd7d05880bfa   755,0
#
#     Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 2                      185  NaN    Безопасность компьютерных систем
# 31                     188  NaN    Безопасность компьютерных систем
# 85                     182  NaN                   Теория баз данных
#
#    Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 2                 Матричные вычисления       Моделирование временных рядов
# 31   Высокопроизводительные вычисления                            Язык SQL
# 85       Моделирование временных рядов         Statistical Learning Theory
#
#           Весенний курс по выбору, приоритет 1  \
# 2                       Дискретная оптимизация
# 31                           Компьютерные сети
# 85  Дополнительные главы прикладной статистики
#
#    Весенний курс по выбору, приоритет 2 Весенний курс по выбору, приоритет 3  \
# 2                   Машинное обучение 2                     Численные методы
# 31                   Системы баз данных                  Машинное обучение 2
# 85                     Численные методы                   Системы баз данных
#
#    Вы заполняете анкету в первый раз?
# 2                                  Да
# 31                                 Да
# 85                                 Да

# %% [markdown]
# Если же вызвать просто ```loc```[2], то получим ошибку:

# %%
# subset.loc[2]

# %% [markdown]
# С помощью ```iloc``` тоже можно делать срезы, но в них последний элемент не включается (как и в обычных срезах в Python, **в отличие от loc**):

# %%
data3.iloc[2:4]
# Out:
#                 Timestamp                                ID Рейтинг  \
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# 2                     Численные методы                                 Да
# 3                  Машинное обучение 2                                 Да

# %% [markdown]
# Срезы можно брать не только по строкам, но и по столбцам. Обратите внимание на различия индексации столбцов в ```loc``` и ```iloc```:

# %%
data3.columns
# Out:
# Index(['Timestamp', 'ID', 'Рейтинг', 'Группа (в формате 182)', 'МИ?',
#        'Осенний курс по выбору, приоритет 1',
#        'Осенний курс по выбору, приоритет 2',
#        'Осенний курс по выбору, приоритет 3',
#        'Весенний курс по выбору, приоритет 1',
#        'Весенний курс по выбору, приоритет 2',
#        'Весенний курс по выбору, приоритет 3',
#        'Вы заполняете анкету в первый раз?'],
#       dtype='object')

# %%
data3.iloc[2:4,2:6]
# Out:
#   Рейтинг  Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1
# 2   624,0                     185  NaN    Безопасность компьютерных систем
# 3   579,0                     182  NaN         Statistical Learning Theory

# %%
data3.loc[2:4, 'Рейтинг':'Осенний курс по выбору, приоритет 1']
# Out:
#   Рейтинг  Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1
# 2   624,0                     185  NaN    Безопасность компьютерных систем
# 3   579,0                     182  NaN         Statistical Learning Theory
# 4   632,0                     183  NaN   Высокопроизводительные вычисления

# %% [markdown]
# Через квадратные скобки можно обращаться к одной или нескольким колонкам:

# %%
data3['Рейтинг'].head(3)
# Out:
# 0    704,0
# 1    646,0
# 2    624,0
# Name: Рейтинг, dtype: object

# %%
data3[['Рейтинг', 'Осенний курс по выбору, приоритет 1']].head(3)
# Out:
#   Рейтинг Осенний курс по выбору, приоритет 1
# 0   704,0                            Язык SQL
# 1   646,0   Высокопроизводительные вычисления
# 2   624,0    Безопасность компьютерных систем

# %% [markdown]
# Есть и более интересные способы индексации. Например, давайте выберем студентов из группы 182:

# %%
data3['Группа (в формате 182)'] == 182
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 218    False
# 219    False
# 220    False
# 221    False
# 222    False
# Name: Группа (в формате 182), Length: 223, dtype: bool

# %%
data3[data3['Группа (в формате 182)'] == 182].sample(3)
# Out:
#                   Timestamp                                ID Рейтинг  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936   784,0
# 134 2020-05-18 21:17:01.633  f3cc62fabaa597e8fe0b20ac2e6f46d3   741,0
# 197 2020-05-18 23:43:04.866  4ab8340cfb08da86c14a2cc3c3fad908   683,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 80                      182  NaN    Безопасность компьютерных систем
# 134                     182  NaN    Безопасность компьютерных систем
# 197                     182  NaN         Statistical Learning Theory
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 80          Statistical Learning Theory                Матричные вычисления
# 134                            Язык SQL                   Теория баз данных
# 197    Безопасность компьютерных систем                            Язык SQL
#
#             Весенний курс по выбору, приоритет 1  \
# 80                        Дискретная оптимизация
# 134  Промышленное программирование на языке Java
# 197                       Дискретная оптимизация
#
#             Весенний курс по выбору, приоритет 2  \
# 80   Промышленное программирование на языке Java
# 134                       Дискретная оптимизация
# 197  Промышленное программирование на языке Java
#
#            Весенний курс по выбору, приоритет 3  \
# 80   Дополнительные главы прикладной статистики
# 134                           Компьютерные сети
# 197                     Анализ данных в бизнесе
#
#     Вы заполняете анкету в первый раз?
# 80                                  Да
# 134                                 Да
# 197                                 Да

# %% [markdown]
# С DataFrame'ами и Series'ами одинаковой структуры можно производить математические операции:

# %%
#strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
#strange_feature.head()

# %% [markdown]
# Видимо, 'Рейтинг' представлен в виде строки. Исправим это:

# %%
#data3['Рейтинг'].apply(lambda x: float(str(x).replace(',', '.')))

# %%
#data3['Рейтинг'].apply(lambda x: float(str(x).replace(',', '.')))

#strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
#strange_feature.head()

# %% [markdown]
# Получаем ту же ошибку, ведь метод apply не модифицирует таблицу, а просто возвращает новый столбец. Обходят это обычно так:

# %%
data3['Рейтинг'] = data3['Рейтинг'].apply(lambda x: float(str(x).replace(',', '.')))

strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
strange_feature.head()
# Out:
# 0    495797.0
# 1    417497.0
# 2    389561.0
# 3    335423.0
# 4    399607.0
# dtype: float64

# %% [markdown]
# В дальнейшем нам понадобится работать с перцентилями студентов. Чтобы сделать такой столбец, в pandas уже есть подходящий метод:

# %%
data3['percentile'] = data3['Рейтинг'].rank() / data3.shape[0]

# добавим также наш странный признак
data3['new'] = strange_feature

# %% [markdown]
# При желании можно удалить любой признак при помоши метода ```drop```:

# %%
data3 = data3.drop(columns=['new'])
data3.head()
# Out:
#                 Timestamp                                ID  Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503    704.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb    646.0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd    624.0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68    579.0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5    632.0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                     181  NaN                            Язык SQL
# 1                     181  NaN   Высокопроизводительные вычисления
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
# 4                     183  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
# 4    Безопасность компьютерных систем                   Теория баз данных
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
# 4                    Компьютерные сети               Дискретная оптимизация
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?  \
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
# 2                     Численные методы                                 Да
# 3                  Машинное обучение 2                                 Да
# 4                     Численные методы                                 Да
#
#    percentile
# 0    0.820628
# 1    0.495516
# 2    0.320628
# 3    0.123318
# 4    0.401345

# %% [markdown]
# ### Разведочный анализ
#
# Теперь изучим наши данные. Вашим домашним заданием будет распределение студентов по курсам, с учётом их предпочтений, рейтинга и ограничений. Начнём к этому готовиться.

# %% [markdown]
# Для начала посмотрим еще раз на типы данных и подумаем, надо ли их менять:

# %%
data3.dtypes
# Out:
# Timestamp                               datetime64[ns]
# ID                                              object
# Рейтинг                                        float64
# Группа (в формате 182)                           int64
# МИ?                                            float64
# Осенний курс по выбору, приоритет 1             object
# Осенний курс по выбору, приоритет 2             object
# Осенний курс по выбору, приоритет 3             object
# Весенний курс по выбору, приоритет 1            object
# Весенний курс по выбору, приоритет 2            object
# Весенний курс по выбору, приоритет 3            object
# Вы заполняете анкету в первый раз?              object
# percentile                                     float64
# dtype: object

# %% [markdown]
# Вроде бы нет...
#
# А что с таблицей для 4ого курса? Как вы знаете, на ряд курсов студенты 3 и 4 годов обучения отбираются совместно, поэтому надо собрать данные в одну таблицу. *Можно ли это сделать без подготовки?*

# %%
data3.head()
# Out:
#                 Timestamp                                ID  Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503    704.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb    646.0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd    624.0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68    579.0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5    632.0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                     181  NaN                            Язык SQL
# 1                     181  NaN   Высокопроизводительные вычисления
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
# 4                     183  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
# 4    Безопасность компьютерных систем                   Теория баз данных
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
# 4                    Компьютерные сети               Дискретная оптимизация
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?  \
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
# 2                     Численные методы                                 Да
# 3                  Машинное обучение 2                                 Да
# 4                     Численные методы                                 Да
#
#    percentile
# 0    0.820628
# 1    0.495516
# 2    0.320628
# 3    0.123318
# 4    0.401345

# %%
data4.head()
# Out:
#                 Timestamp                                ID Рейтинг  \
# 0 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403   995,0
# 1 2020-05-14 20:47:13.833  253bbe1a2021d0404712a1e4acd22939  1105,0
# 2 2020-05-14 20:52:42.734  881b1a6fda195b354ae2edb396a69f5d  1083,0
# 3 2020-05-14 21:03:02.916  5a9b8ac11ad05b39a58b0e04a263bf4c  1169,0
# 4 2020-05-14 21:10:54.945  1bbbfae51794b83c769b634be8da7b8d  1077,0
#
#    Группа (в формате 173) blended-курс   Осенний курс по выбору, приоритет 1  \
# 0                     172       DevOps      Безопасность компьютерных систем
# 1                     176       DevOps      Безопасность компьютерных систем
# 2                     172       DevOps      Безопасность компьютерных систем
# 3                     171       DevOps  Глубинное обучение в обработке звука
# 4                     176       DevOps      Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2  \
# 0  Глубинное обучение в обработке звука
# 1         Моделирование временных рядов
# 2     Анализ неструктурированных данных
# 3           Statistical Learning Theory
# 4     Высокопроизводительные вычисления
#
#                Осенний курс по выбору, приоритет 3  \
# 0            Байесовские методы машинного обучения
# 1                      Statistical Learning Theory
# 2             Глубинное обучение в обработке звука
# 3  Сбор и обработка данных с помощью краудсорсинга
# 4                Анализ неструктурированных данных
#
#                 Весенний курс по выбору, приоритет 1  \
# 0                                Компьютерное зрение
# 1  Проектирование и разработка высоконагруженных ...
# 2                                Компьютерное зрение
# 3                             Конфликты и кооперация
# 4  Проектирование и разработка высоконагруженных ...
#
#                 Весенний курс по выбору, приоритет 2  \
# 0                           Обучение с подкреплением
# 1                                   Численные методы
# 2  Проектирование и разработка высоконагруженных ...
# 3                           Обучение с подкреплением
# 4               Методы сжатия и передачи медиаданных
#
#                 Весенний курс по выбору, приоритет 3  \
# 0  Проектирование и разработка высоконагруженных ...
# 1               Методы сжатия и передачи медиаданных
# 2            Генеративные модели в машинном обучении
# 3            Генеративные модели в машинном обучении
# 4                             Конфликты и кооперация
#
#   Вы заполняете анкету в первый раз?
# 0                                 Да
# 1                                 Да
# 2                                 Да
# 3                                 Да
# 4                                 Да

# %% [markdown]
# Кажется, рейтинги имеют разные распределения. Проверим это:

# %%
data3['Рейтинг'].describe()
# Out:
# count    223.000000
# mean     648.816143
# std       58.255552
# min      495.000000
# 25%      609.000000
# 50%      647.000000
# 75%      691.000000
# max      784.000000
# Name: Рейтинг, dtype: float64

# %%
data4['Рейтинг'].describe()
# Out:
# count        138
# unique       117
# top       1085,0
# freq           3
# Name: Рейтинг, dtype: object

# %% [markdown]
# Да, рейтинг для 4 курса тоже надо привести к числовому типу.

# %%
data4['Рейтинг'] = data4['Рейтинг'].apply(lambda x: float(str(x).replace(',', '.')))
data4['Рейтинг'].describe()
# Out:
# count     138.000000
# mean     1155.188406
# std        91.659203
# min       963.000000
# 25%      1086.500000
# 50%      1155.500000
# 75%      1217.500000
# max      1456.000000
# Name: Рейтинг, dtype: float64

# %% [markdown]
# Видно, что квантили в самом деле отличаются — поэтому сами рейтинги не стоит использовать после объединения таблиц, надо работать только с перцентилями. Вычислим их и объединим таблицы с помощью метода ```concat```:

# %%
data4['percentile'] = data4['Рейтинг'].rank() / data4.shape[0]


data = pd.concat([data3, data4])
data.head(2)
# Out:
#                 Timestamp                                ID  Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503    704.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb    646.0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                   181.0  NaN                            Язык SQL
# 1                   181.0  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 0               Дискретная оптимизация                     Численные методы
# 1               Дискретная оптимизация                     Численные методы
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?  \
# 0                  Машинное обучение 2                                 Да
# 1                  Машинное обучение 2                                Нет
#
#    percentile  Группа (в формате 173) blended-курс
# 0    0.820628                     NaN          NaN
# 1    0.495516                     NaN          NaN

# %%
data.shape
# Out:
# (361, 15)

# %% [markdown]
# Теперь для удобства переименуем столбцы (обратите внимание на ```inplace=True```):

# %%
data.rename(columns={'Timestamp':'timestamp',
                     'ID':'id',
                     'Рейтинг':'rating',
                     'МИ?':'is_mi',
                     'Группа (в формате 182)':'18_group',
                     'Группа (в формате 173)':'17_group',
                     'Осенний курс по выбору, приоритет 1':'fall_1',
                     'Осенний курс по выбору, приоритет 2':'fall_2',
                     'Осенний курс по выбору, приоритет 3':'fall_3',
                     'Весенний курс по выбору, приоритет 1':'spring_1',
                     'Весенний курс по выбору, приоритет 2':'spring_2',
                     'Весенний курс по выбору, приоритет 3':'spring_3',
                     'Вы заполняете анкету в первый раз?':'is_first_time',
                     'blended-курс':'blended'},
           inplace=True)

# %% [markdown]
# Поскольку у (почти всех) столбцов теперь названия являются корректными именами переменных в Python, мы можем использовать ещё один способ обращения к столбцам таблицы как к полям класса:

# %%
data.fall_1
# Out:
# 0                                             Язык SQL
# 1                    Высокопроизводительные вычисления
# 2                     Безопасность компьютерных систем
# 3                          Statistical Learning Theory
# 4                    Высокопроизводительные вычисления
#                             ...
# 133                        Statistical Learning Theory
# 134                  Анализ неструктурированных данных
# 135    Сбор и обработка данных с помощью краудсорсинга
# 136                   Безопасность компьютерных систем
# 137                  Анализ неструктурированных данных
# Name: fall_1, Length: 361, dtype: object

# %% [markdown]
# Нередко работы с данными начинают с поиска пропущенных значений (NaN и др.) и их заполнения. Для начала посмотрим на их наличие:

# %%
data.isna().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# dtype: int64

# %% [markdown]
# Видно, что тут содержательных пропусков нет — есть только проблемы с колонками, специфичными для одного из курсов.
#
# Заполнять пропуски необходимо в соответствии со смыслом колонки. Можно заполнять с помощью среднего, медианного, константного или других значений. Для этого обычно используется метод ```fillna()``` с которым вы познакомитесь в домашнем задании.

# %% [markdown]
# Также для разведочного анализа может помочь метод ```groupby(column)```.
#
# Он группирует объекты по указанной(-ым) колонке(-ам). Необходимо также указать какую статистику для группировки выводить. Это может быть количество (count), среднее (mean) или другие. Из огромной функциональности этого метода разберем только несколько базовых приемов:

# %%
data.groupby('fall_1').count()[['id', 'is_mi']]
# Out:
#                                                      id  is_mi
# fall_1
# Statistical Learning Theory                          26      1
# Анализ неструктурированных данных                    32      0
# Байесовские методы машинного обучения                17      0
# Безопасность компьютерных систем                    110      4
# Высокопроизводительные вычисления                    42      0
# Глубинное обучение в обработке звука                 12      0
# Матричные вычисления                                 14      1
# Моделирование временных рядов                        24      7
# Принятие решений в условиях риска и неопределён...    5      0
# Сбор и обработка данных с помощью краудсорсинга      35      1
# Теория баз данных                                    13      2
# Язык SQL                                             31      2

# %% [markdown]
# *Какие выводы вы можете сделать отсюда?*

# %% [markdown]
# Сделаем ```groupby``` с усреднением:

# %%
data.groupby(by='fall_1').mean()
# Out:
#                                                          rating    18_group  \
# fall_1
# Statistical Learning Theory                          886.769231  183.428571
# Анализ неструктурированных данных                   1124.000000         NaN
# Байесовские методы машинного обучения               1190.647059         NaN
# Безопасность компьютерных систем                     785.872727  184.481481
# Высокопроизводительные вычисления                    968.309524  184.055556
# Глубинное обучение в обработке звука                1163.250000         NaN
# Матричные вычисления                                 671.857143  183.357143
# Моделирование временных рядов                        671.125000  184.869565
# Принятие решений в условиях риска и неопределён...   762.600000  186.333333
# Сбор и обработка данных с помощью краудсорсинга      781.628571  185.038462
# Теория баз данных                                    629.384615  184.000000
# Язык SQL                                             609.612903  185.258065
#
#                                                     is_mi  percentile  \
# fall_1
# Statistical Learning Theory                           1.0    0.490706
# Анализ неструктурированных данных                     NaN    0.412477
# Байесовские методы машинного обучения                 NaN    0.613598
# Безопасность компьютерных систем                      1.0    0.535848
# Высокопроизводительные вычисления                     NaN    0.600555
# Глубинное обучение в обработке звука                  NaN    0.539553
# Матричные вычисления                                  1.0    0.613069
# Моделирование временных рядов                         1.0    0.507908
# Принятие решений в условиях риска и неопределён...    NaN    0.188945
# Сбор и обработка данных с помощью краудсорсинга       1.0    0.526562
# Теория баз данных                                     1.0    0.397723
# Язык SQL                                              1.0    0.295241
#
#                                                       17_group
# fall_1
# Statistical Learning Theory                         173.000000
# Анализ неструктурированных данных                   172.593750
# Байесовские методы машинного обучения               171.411765
# Безопасность компьютерных систем                    174.413793
# Высокопроизводительные вычисления                   174.958333
# Глубинное обучение в обработке звука                172.916667
# Матричные вычисления                                       NaN
# Моделирование временных рядов                       175.000000
# Принятие решений в условиях риска и неопределён...  175.000000
# Сбор и обработка данных с помощью краудсорсинга     172.555556
# Теория баз данных                                          NaN
# Язык SQL                                                   NaN

# %% [markdown]
# Отсюда мы узнаём среднюю перцентиль для того или иного курса по выбору.
# Обратите внимание, что средний рейтинг тут не очень показателен из-за разных его распределений у разных годов обучения.
#
# Что выводится в следующей строке?

# %%
data.groupby(by='fall_1').count()[['17_group', '18_group']].sum()
# Out:
# 17_group    138
# 18_group    223
# dtype: int64

# %% [markdown]
# Полезным бывает посмотреть на основные статистики по каждому *числовому*  признаку (столбцу). Метод ```describe``` позволяет быстро сделать это:

# %%
data.describe()
# Out:
#             rating    18_group  is_mi  percentile    17_group
# count   361.000000  223.000000   18.0  361.000000  138.000000
# mean    842.387812  184.520179    1.0    0.502770  173.355072
# std     256.919279    2.271701    0.0    0.289060    1.795374
# min     495.000000  181.000000    1.0    0.004484  171.000000
# 25%     634.000000  183.000000    1.0    0.253623  172.000000
# 50%     702.000000  185.000000    1.0    0.502242  173.000000
# 75%    1107.000000  187.000000    1.0    0.753363  175.000000
# max    1456.000000  188.000000    1.0    1.000000  177.000000

# %% [markdown]
# *Какие элементы таблицы выше могут быть полезны? Для чего?*

# %% [markdown]
# Студентам специализации МОП (машинное обучение и приложения) нельзя выбирать курс "Машинное обучение 2" в качестве весеннего курса по выбору. Давайте проверим, есть ли те, кто попытался:

# %%
# !wget  -O 'ml_students_anon.xlsx' -q 'https://www.dropbox.com/s/izc21kik0b8iw10/_ml_students_anon.xlsx?dl=0'

ml_students = pd.read_excel('ml_students_anon.xlsx')

# %% [markdown]
# Если вы знакомы с SQL, то знаете, что там крайне часто используется операция JOIN для соединения нескольких таблиц по тому или иному значению. В pandas такое тоже есть, функция называется ```merge```.
#
# У нас есть две таблицы: (1) приоритеты студентов по элективам и (2) специализации, на которые распределены студенты. Эти таблицы содержат разную информацию про студентов, но в обеих конкретный студент имеет один и тот же ID. Допустим, мы теперь хотим соединить эти таблицы — то есть получить новую таблицу, в которой для каждого студента есть информация и о приоритетах по элективам, и о его специализации. Как раз для этого и понадобится операция ```merge```.
#
# Идея соединения таблиц также отражена на картинке ниже.

# %% [markdown]
# <img src="https://i.imgur.com/WYyBFTE.png" style="width: 400px">

# %%
data = data.merge(ml_students, on='id', how='left')

# %%
data[(data['is_ml_student'] == True) &
     (
         (data['spring_1'] == 'Машинное обучение 2')
         |
         (data['spring_2'] == 'Машинное обучение 2')
         |
         (data['spring_3'] == 'Машинное обучение 2')
     )].head(2)
# Out:
#                  timestamp                                id  rating  \
# 20 2020-05-15 21:55:16.699  f0f6f3881894172a0f04e79b554b49e6   676.0
# 27 2020-05-16 13:02:24.706  5daee1bd98559bb2c52373e416942225   659.0
#
#     18_group  is_mi                                           fall_1  \
# 20     181.0    NaN                 Безопасность компьютерных систем
# 27     182.0    NaN  Сбор и обработка данных с помощью краудсорсинга
#
#                                              fall_2  \
# 20  Сбор и обработка данных с помощью краудсорсинга
# 27                      Statistical Learning Theory
#
#                                                fall_3             spring_1  \
# 20  Принятие решений в условиях риска и неопределё...  Машинное обучение 2
# 27                      Моделирование временных рядов  Машинное обучение 2
#
#                                        spring_2  \
# 20                             Численные методы
# 27  Промышленное программирование на языке Java
#
#                                       spring_3 is_first_time  percentile  \
# 20  Дополнительные главы прикладной статистики            Да    0.663677
# 27                     Анализ данных в бизнесе           Нет    0.556054
#
#     17_group blended is_ml_student
# 20       NaN     NaN          True
# 27       NaN     NaN          True

# %% [markdown]
# Попробуем понять, есть ли явная зависимость между рейтингом и номером группы. Для начала посмотрим на корреляции (функция corr считает по умолчанию корреляцию Пирсона):

# %%
corrmat = data[['rating', '18_group', '17_group']].corr()
corrmat
# Out:
#             rating  18_group  17_group
# rating    1.000000 -0.253637  0.013607
# 18_group -0.253637  1.000000       NaN
# 17_group  0.013607       NaN  1.000000

# %% [markdown]
# *Проинтерпретируйте результаты. Можно ли им доверять, разумно ли смотреть на корреляции?*

# %% [markdown]
# Здесь числовых признаков не так много, но на практике их бывают десятки, а то и сотни. В таком случае бывает полезно посмотреть на эту матрицу корреляций в виде heatmap:

# %%
# импорт библиотек для графиков
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(corrmat, square=True)
plt.show()

# %% [markdown]
# К графикам надо относиться серьёзно, они должны быть понятными и информативными. Рассмотрим несколько примеров.
#
# *Прокомментируйте что вам кажется хорошим и плохим на данных графиках.*

# %%
plt.hist(data['timestamp'])
plt.title('Гистограмма распределения ответов по времени')
plt.show()

# %%
sns.set()

fig, ax = plt.subplots()
ax = sns.countplot(y='fall_1', data=data)
ax.set_title('Осенний курс по выбору, приоритет 1')
ax.set_ylabel('')

ax.set(xlabel='Количество заявок')


plt.show()

# %%
crs3 = data[data['17_group'].isna()]
gr_raiting_med = crs3.groupby('18_group').median()['rating']
gr_raiting_sum = crs3.groupby('18_group').sum()['rating']

fig, axs = plt.subplots(2, 1, figsize=(10, 6), sharex=True)
fig.suptitle('Зависимость номера группы от рейтинга')
#fig.text('Рейтинг')


axs[0].plot(gr_raiting_sum)
axs[0].set_ylabel('Суммарный рейтинг')

axs[1].plot(gr_raiting_med)
axs[1].set_ylabel('Медианный рейтинг')


plt.xlabel('Номер группы')

plt.show()

# %% [markdown]
# Если вы будете делать графики без подписанных осей, с налезающими друг на друга метками, неаккуратными линиями и т.д., то имеете все шансы попасть сюда: https://t.me/funny_homeworks

# %% [markdown]
# Сохраним полученную таблицу, чтобы вы могли продолжить с ней работу дома:

# %%
data.to_excel('end_seminar.xlsx', index=False)

# %% [markdown]
# ### Разведочный анализ данных

# %% [markdown]
# Рассказ во многом взят из ноутбука https://www.kaggle.com/gaborfodor/from-eda-to-the-top-lb-0-367/notebook

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from datetime import timedelta
import datetime as dt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]
import seaborn as sns

# %% [markdown]
# Загрузим данные и изучим доступные нам признаки.

# %%
# !wget  -O 'train.csv' -q 'https://www.dropbox.com/s/en5f9nhn915cnkf/_train.csv?dl=0'

# %%
train = pd.read_csv('train.csv')

# %%
train.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration'],
#       dtype='object')

# %% [markdown]
# Смысл столбцов:
#
# * id - идентификатор поездки
# * vendor_id - код провайдера, от которого пришла информация о поездке
# * pickup_datetime - время старта поездки
# * dropoff_datetime - время окончания поездки
# * passenger_count - число пассажиров (вводится водителем)
# * pickup_longitude - долгота точки посадки
# * pickup_latitude - широта точки посадки
# * dropoff_longitude - долгота точки высадки
# * dropoff_latitude - долгота точки высадки
# * store_and_fwd_flag - равно Y, если информация о поездке какое-то время хранилась в памяти таксометра из-за отсутствия связи; иначе принимает значение N
# * trip_duration - продолжительность поездки в секундах

# %%
train.shape
# Out:
# (1458644, 11)

# %% [markdown]
# Данных довольно много, поэтому нужно задумываться об эффективности всех вычислений. Ниже мы увидим на примере, что правильное использование возможностей pandas позволит существенно ускорить вычисления.

# %% [markdown]
# Посмотрим внимательно на столбцы из нашей таблицы и попробуем проверить, нет ли там противоречий и проблем. Например, в голову приходят следующие вопросы:
# * можно ли считать ID уникальным идентификатором поездки, или же есть записи с одинаковыми ID?
# * есть ли где-то пропуски?
# * действительно ли столбец store_and_fwd_flag принимает только значения Y и N?

# %%
print('Id is unique.') if train.id.nunique() == train.shape[0] else print('oops')
# Out:
# Id is unique.

# %%
print('We do not need to worry about missing values.') if train.count().min() == train.shape[0] else print('oops')
# Out:
# We do not need to worry about missing values.

# %%
print('The store_and_fwd_flag has only two values {}.'.format(str(set(train.store_and_fwd_flag.unique()))))
# Out:
# The store_and_fwd_flag has only two values {'N', 'Y'}.

# %%
train.store_and_fwd_flag
# Out:
# 0          N
# 1          N
# 2          N
# 3          N
# 4          N
#           ..
# 1458639    N
# 1458640    N
# 1458641    N
# 1458642    N
# 1458643    N
# Name: store_and_fwd_flag, Length: 1458644, dtype: object

# %% [markdown]
# Посмотрим на типы данных в каждом столбце.

# %%
train.dtypes
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# trip_duration           int64
# dtype: object

# %%
train.pickup_datetime
# Out:
# 0          2016-03-14 17:24:55
# 1          2016-06-12 00:43:35
# 2          2016-01-19 11:35:24
# 3          2016-04-06 19:32:31
# 4          2016-03-26 13:30:55
#                   ...
# 1458639    2016-04-08 13:31:04
# 1458640    2016-01-10 07:35:15
# 1458641    2016-04-22 06:57:41
# 1458642    2016-01-05 15:56:26
# 1458643    2016-04-05 14:44:25
# Name: pickup_datetime, Length: 1458644, dtype: object

# %% [markdown]
# Видно, что pandas отнёс столбцы с датами к общему типу object. Будет лучше привести их к типу datetime, чтобы использовать удобные функции для манипуляций с датами. Заодно сделаем проверку — действительно ли столбец check_trip_duration показывает продолжительность поездки, или же он входит в противоречие со столбцами pickup_datetime и dropoff_datetime.

# %%
train['pickup_datetime'] = pd.to_datetime(train.pickup_datetime)
train['pickup_date'] = train['pickup_datetime'].dt.date
train.head(1)
# Out:
#           id  vendor_id     pickup_datetime     dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55  2016-03-14 17:32:30
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937          -73.96463
#
#    dropoff_latitude store_and_fwd_flag  trip_duration pickup_date
# 0         40.765602                  N            455  2016-03-14

# %%
train['dropoff_datetime'] = pd.to_datetime(train.dropoff_datetime)
train['store_and_fwd_flag'] = 1 * (train.store_and_fwd_flag.values == 'Y')
train['check_trip_duration'] = (train['dropoff_datetime'] - train['pickup_datetime']).map(lambda x: x.total_seconds())
duration_difference = train[np.abs(train['check_trip_duration'].values  - train['trip_duration'].values) > 1]
print('Trip_duration and datetimes are ok.') if len(duration_difference[['pickup_datetime', 'dropoff_datetime', 'trip_duration', 'check_trip_duration']]) == 0 else print('Ooops.')
# Out:
# Trip_duration and datetimes are ok.

# %%
#train.apply()

# %%
train.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude  store_and_fwd_flag  trip_duration pickup_date  \
# 0         40.765602                   0            455  2016-03-14
# 1         40.731152                   0            663  2016-06-12
# 2         40.710087                   0           2124  2016-01-19
# 3         40.706718                   0            429  2016-04-06
# 4         40.782520                   0            435  2016-03-26
#
#    check_trip_duration
# 0                455.0
# 1                663.0
# 2               2124.0
# 3                429.0
# 4                435.0

# %% [markdown]
# Ещё имеет смысл проверить целевую переменную trip_duration. Нет ли там выбросов? Какими по продолжительности бывают поездки? Выглядит ли распределение этой переменной осмысленно?

# %%
plt.hist(train['trip_duration'].values, bins=100)
plt.xlabel('trip_duration')
plt.ylabel('number of train records')
plt.show()

# %% [markdown]
# Когда в каком-то столбце распределение имеет тяжёлые хвосты или есть выбросы, обычные гистограммы не очень информативны. В этом случае может быть полезно нарисовать распределение в логарифмической шкале.

# %%
train['log_trip_duration'] = np.log1p(train['trip_duration'].values)
plt.hist(train['log_trip_duration'].values, bins=100)
plt.xlabel('log(trip_duration)')
plt.ylabel('number of train records')
plt.show()

# %% [markdown]
# В целом распределение разумное, продолжительность поездки находится примерно в следующем интервале:

# %%
print("В секундах:", np.exp(5), np.exp(9))
print("В минутах:", np.exp(5) // 60, np.exp(9) // 60)
# Out:
# В секундах: 148.4131591025766 8103.083927575384
# В минутах: 2.0 135.0

# %% [markdown]
# Самая длинная поездка (в часах):

# %%
train['trip_duration'].max() // 3600
# Out:
# 979

# %%
train[train.trip_duration >= 979 * 3600]
# Out:
#                id  vendor_id     pickup_datetime    dropoff_datetime  \
# 978383  id0053347          1 2016-02-13 22:46:52 2016-03-25 18:18:14
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 978383                1        -73.783905        40.648632         -73.978271
#
#         dropoff_latitude  store_and_fwd_flag  trip_duration pickup_date  \
# 978383         40.750202                   0        3526282  2016-02-13
#
#         check_trip_duration  log_trip_duration
# 978383            3526282.0          15.075755

# %% [markdown]
# Это выброс. Мог сломаться таксометр, водитель мог забыть остановить поездку по каким-то причинам и т.д. В любом случае, будет странно обучаться на таких данных, обычно их выкидывают из выборки. Кандидатов на выбрасывание не так уж много — например, если взять поездки длиной 10 часа и больше, то их окажется около двух тысяч, и определённо надо выяснять, что это такое.

# %%
train[train.trip_duration >= 10 * 3600]
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 531      id3307903          2 2016-02-20 04:03:06 2016-02-21 03:33:00
# 1134     id1091477          2 2016-05-07 18:36:22 2016-05-08 18:32:11
# 1865     id3431345          2 2016-06-07 12:58:48 2016-06-08 12:58:00
# 3442     id1487069          2 2016-02-13 00:21:49 2016-02-14 00:19:05
# 4172     id3674870          2 2016-03-18 11:54:20 2016-03-19 11:34:17
# ...            ...        ...                 ...                 ...
# 1455097  id2798196          2 2016-03-20 03:51:36 2016-03-21 00:00:00
# 1456458  id2055880          2 2016-02-08 19:11:31 2016-02-09 19:08:44
# 1457207  id1910950          2 2016-06-08 16:29:12 2016-06-09 16:11:03
# 1457752  id1215198          2 2016-02-02 11:31:10 2016-02-03 11:29:44
# 1458076  id2332290          2 2016-04-24 00:58:34 2016-04-25 00:56:16
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 531                    3        -74.008102        40.741489
# 1134                   1        -73.990242        40.750919
# 1865                   6        -73.954956        40.777649
# 3442                   1        -73.968590        40.799217
# 4172                   1        -73.989090        40.736992
# ...                  ...               ...              ...
# 1455097                2        -73.969299        40.757301
# 1456458                3        -73.973282        40.760792
# 1457207                1        -73.958061        40.800869
# 1457752                6        -73.972069        40.794220
# 1458076                1        -73.990479        40.760876
#
#          dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 531             -74.009956         40.714611                   0
# 1134            -73.976280         40.750889                   0
# 1865            -73.981033         40.743713                   0
# 3442            -73.979584         40.784714                   0
# 4172            -73.972336         40.751511                   0
# ...                    ...               ...                 ...
# 1455097         -73.870277         40.709808                   0
# 1456458         -73.988518         40.764210                   0
# 1457207         -73.964119         40.805515                   0
# 1457752         -73.961014         40.806728                   0
# 1458076         -73.983025         40.764557                   0
#
#          trip_duration pickup_date  check_trip_duration  log_trip_duration
# 531              84594  2016-02-20              84594.0          11.345630
# 1134             86149  2016-05-07              86149.0          11.363845
# 1865             86352  2016-06-07              86352.0          11.366199
# 3442             86236  2016-02-13              86236.0          11.364855
# 4172             85197  2016-03-18              85197.0          11.352733
# ...                ...         ...                  ...                ...
# 1455097          72504  2016-03-20              72504.0          11.191411
# 1456458          86233  2016-02-08              86233.0          11.364820
# 1457207          85311  2016-06-08              85311.0          11.354070
# 1457752          86314  2016-02-02              86314.0          11.365759
# 1458076          86262  2016-04-24              86262.0          11.365156
#
# [2012 rows x 14 columns]

# %% [markdown]
# Попробуем нарисовать, откуда обычно стартуют поездки.

# %%
N = 100000
city_long_border = (-74.03, -73.75)
city_lat_border = (40.63, 40.85)
plt.figure(figsize=(15,15))
plt.scatter(train['pickup_longitude'].values[:N], train['pickup_latitude'].values[:N],
              color='blue', s=1, label='train', alpha=0.1)
plt.ylabel('latitude')
plt.xlabel('longitude')
plt.ylim(city_lat_border)
plt.xlim(city_long_border)
plt.show()

# %% [markdown]
# Теперь нарисуем как следует, на карте.

# %%
#!pip  install ipyleaflet

# %%
from ipyleaflet import Map, Circle, LayerGroup, basemaps

# %%
def show_circles_on_map(data, latitude_column, longitude_column, color):
    """
    The function draws map with circles on it.
    The center of the map is the mean of coordinates passed in data.

    data: DataFrame that contains columns latitude_column and longitude_column
    latitude_column: string, the name of column for latitude coordinates
    longitude_column: string, the name of column for longitude coordinates
    color: string, the color of circles to be drawn
    """

    center = (data[latitude_column].mean(), data[longitude_column].mean())
    result_map = Map(center=center, zoom=10, basemap=basemaps.Esri.NatGeoWorldMap)

    circles = []
    for _, row in data.iterrows():
        circles.append(Circle(
            location=(row[latitude_column], row[longitude_column]),
            fill_color=color,
            fill_opacity=0.2,
            radius=300,
            stroke=False
        ))
    circles_layer = LayerGroup(layers=circles)
    result_map.add_layer(circles_layer)

    return result_map

# %%
show_circles_on_map(train.sample(1000), "pickup_latitude", "pickup_longitude", "blue")
# Out:
# Map(center=[40.75303678512573, -73.97358015441894], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %% [markdown]
# Кстати, случайный ли порядок записей в таблице? Это важно понимать, например, для разбиения выборки на обучающую и тестовую части. Если порядок не является случайным, а мы отнесём к обучающей части первую половину таблицы, то есть риск, что данные в обучении и тесте будут иметь разные распределения, а значит, модель сможет хорошо работать только на одной из частей.

# %%
plt.figure(figsize=(15,5))
days_since_min_ride = (train['pickup_datetime'] - train['pickup_datetime'].min()).apply(lambda x: x.total_seconds() // (60*60*24))
plt.plot(days_since_min_ride[::1000], 'o-')
plt.title('Связь номера строки и времени поездки')
plt.xlabel('Номер записи в таблице')
plt.ylabel('Дней с момента ранней поездки')
# Out:
# Text(0, 0.5, 'Дней с момента ранней поездки')

# %% [markdown]
# Вроде бы всё довольно случайно.

# %% [markdown]
# Посчитаем какие-нибудь признаки. Скорее всего продолжительность поездки неплохо зависит от расстояния — посчитаем его. Кстати, важно заметить, что само расстояние не может быть признаком, поскольку в тестовой выборе нет информации о пункте назначения. Но мы пока исследуем данные и, может, увидим в расстояниях что-то интересное.
#
# Можно выбрать научный подход и посчитать честное расстояние на сфере между двумя точками. Это называется [haversine distance](https://en.wikipedia.org/wiki/Haversine_formula).
#
# Можно решить, что Земля плоская, и считать стандартные расстояния. В этом случае очень неплохо подойдёт [манхэттенское расстояние](https://en.wikipedia.org/wiki/Taxicab_geometry) — оно учитывает, что машины всё-таки не летают.

# %%
def haversine_array(lat1, lng1, lat2, lng2):
    lat1, lng1, lat2, lng2 = map(np.radians, (lat1, lng1, lat2, lng2))
    AVG_EARTH_RADIUS = 6371  # in km
    lat = lat2 - lat1
    lng = lng2 - lng1
    d = np.sin(lat * 0.5) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(lng * 0.5) ** 2
    h = 2 * AVG_EARTH_RADIUS * np.arcsin(np.sqrt(d))
    return h

def dummy_manhattan_distance(lat1, lng1, lat2, lng2):
    a = haversine_array(lat1, lng1, lat1, lng2)
    b = haversine_array(lat1, lng1, lat2, lng1)
    return a + b

train.loc[:, 'distance_haversine'] = haversine_array(train['pickup_latitude'].values, train['pickup_longitude'].values, train['dropoff_latitude'].values, train['dropoff_longitude'].values)
train.loc[:, 'distance_dummy_manhattan'] = dummy_manhattan_distance(train['pickup_latitude'].values, train['pickup_longitude'].values, train['dropoff_latitude'].values, train['dropoff_longitude'].values)

# %% [markdown]
# Обсудим немного скорость вычислений в pandas. Есть несколько способов применить функцию к каждой строке в таблице. Если вы до этого изучали преимущественно C/C++, то первое, что должно прийти вам в голову, — написать цикл.

# %%
train1 = train.copy()

# %%
# %%timeit

for i in range(100):
    train1[i, 'distance_haversine'] = haversine_array(train1['pickup_latitude'].iloc[i],
                                                      train1['pickup_longitude'].iloc[i],
                                                      train1['dropoff_latitude'].iloc[i],
                                                      train1['dropoff_longitude'].iloc[i])
# Out:
# <magic-timeit>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# <magic-timeit>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# <magic-timeit>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# <magic-timeit>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# 230 ms ± 30.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Обратите внимание, что мы посчитали расстояния всего лишь для первых 100 записей, и это уже было не очень быстро.

# %% [markdown]
# Можно воспользоваться функцией ```apply```.

# %%
# %%timeit

train1.iloc[:5000, :].apply(lambda x:
                            haversine_array(x['pickup_latitude'],
                                            x['pickup_longitude'],
                                            x['dropoff_latitude'],
                                            x['dropoff_longitude']),
                            axis=1)
# Out:
# 298 ms ± 100 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# За то же самое время мы успеваем обработать уже 5000 записей, а не 100.

# %% [markdown]
# Но лучший способ — это векторизовать вычисления. Подробнее об этом мы будем говорить на следующих семинарах.

# %%
# %%timeit
train.loc[:, 'distance_haversine'] = haversine_array(train['pickup_latitude'].values, train['pickup_longitude'].values, train['dropoff_latitude'].values, train['dropoff_longitude'].values)
# Out:
# 156 ms ± 24.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Чуть подробнее об ускорении вычислений можно почитать здесь: https://engineering.upside.com/a-beginners-guide-to-optimizing-pandas-code-for-speed-c09ef2c6a4d6

# %% [markdown]
# Посмотрим на распределения расстояний.

# %%
plt.hist(np.log1p(train.distance_haversine), bins=100)
plt.show()

# %%
plt.hist(np.log1p(train.distance_dummy_manhattan), bins=100)
plt.show()

# %% [markdown]
# Выглядят достаточно одинаково.
#
# Поисследуем теперь связь между расстоянием и продолжительностью поездки.

# %%
plt.figure(figsize=(10,10))
plt.scatter(train.distance_haversine[:100000], train.trip_duration[:100000], marker='o')
plt.xlabel('haversine distance')
plt.ylabel('trip duration')
# Out:
# Text(0, 0.5, 'trip duration')

# %% [markdown]
# В нижней части графика точки неплохо выстраиваются в линию, но ещё есть некоторое количество выбросов. Нарисуем тот же график без них.

# %%
plt.figure(figsize=(10,10))
plt.scatter(train[train.trip_duration < 20000].distance_haversine[:100000],
            train[train.trip_duration < 20000].trip_duration[:100000], marker='o')
plt.xlabel('haversine distance')
plt.ylabel('trip duration')
# Out:
# Text(0, 0.5, 'trip duration')

# %% [markdown]
# Кажется, тут вполне может сработать линейная регрессия!
#
# Ещё раз напомним, что расстояние не может быть признаком, его не посчитать для тестовой выборки. Но мы пока просто играемся.

# %%
from sklearn import linear_model, metrics

# %%
train_filtered = train[train.trip_duration < 20000]
X = train_filtered.distance_haversine.values[:, np.newaxis]
y = train_filtered.trip_duration.values

regr = linear_model.Ridge()
regr.fit(X, y)
metrics.mean_absolute_error(regr.predict(X), y)
# Out:
# 299.65921803397475

# %%
train_filtered = train[train.trip_duration < 20000]
X = train_filtered.distance_dummy_manhattan.values[:, np.newaxis]
y = train_filtered.trip_duration.values

regr = linear_model.Ridge()
regr.fit(X, y)
metrics.mean_absolute_error(regr.predict(X), y)
# Out:
# 306.0326596057465

# %% [markdown]
# То есть в среднем модель ошибается где-то на 300 секунд при предсказании продолжительности поездки. Как понять, хорошо это или плохо? Например, сравнить с качеством константной модели — например, которая всегда в качестве прогноза выдаёт медианное или среднее время поездки.

# %%
metrics.mean_absolute_error(np.median(y) * np.ones(y.shape), y)
# Out:
# 444.8109724449668

# %%
metrics.mean_absolute_error(np.mean(y) * np.ones(y.shape), y)
# Out:
# 468.0349997665766

# %% [markdown]
# ### Почему важно исследовать данные?

# %% [markdown]
# Иногда бывает, что задача сложная, но при этом хорошего качества можно добиться с помощью простых правил. Причины могут быть разные:
# * Разметка собрана по простому правилу. Например, для задачи предсказания тональности твитов могли сделать разметку через эмодзи — тогда достаточно, скажем, добавить признак "наличие в тексте подстроки ':)'".
# * Задача действительно простая и не требует поиска закономерностей методами машинного обучения.
# * В данных есть утечка (leak) — то есть в признаках содержится информация, которая на самом деле не должна быть доступна при построении прогноза.
#
# Про некоторые истории с утечками можно почитать и посмотреть здесь:
# * https://dyakonov.org/2018/06/28/простые-методы-анализа-данных/
# * https://www.kaggle.com/c/the-icml-2013-whale-challenge-right-whale-redux/discussion/4865
# * https://www.youtube.com/watch?v=UOxf2P9WnK8
